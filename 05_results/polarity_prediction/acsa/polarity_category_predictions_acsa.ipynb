# %% [markdown]
# ### Analysis of Polarity and Category Prediction

# %%
import os
import pandas as pd

# Base columns to keep
col_names = ['task', 'seed']  # hyperparameters dropped
datasets = ["Crowd", "Students", "LLM", "Experts"]
methods = ["BERT-CLF", "Hier-GCN", "LLM-FS", "LLM-FT"]
all_runs = []

for dataset in datasets:
    for method in methods:
        RESULTS_PATH = os.path.join(f"../../methods/{method}/", dataset)
        folder_names = [
            folder for folder in os.listdir(RESULTS_PATH)
            if os.path.isdir(os.path.join(RESULTS_PATH, folder))
            and folder != '.ipynb_checkpoints'
            and folder != 'duplicate_labels'
        ]

        for folder_name in folder_names:
            try:
                cond_parameters = folder_name.split('_')  # gives task, seed, etc.
                # print(folder_name)
                if method == "LLM-FT" or method == "LLM-FS":
                    if not folder_name.__contains__("tasd"):
                        df = pd.read_csv(
                            os.path.join(RESULTS_PATH, folder_name, 'result_pairs.tsv'),
                            sep='\t'
                        )
                        df_small = df[['Label', 'F1']].rename(columns={'Label': 'label', 'F1': 'f1'})
                else:
                    df = pd.read_csv(
                    os.path.join(RESULTS_PATH, folder_name, 'metrics_pairs.tsv'),
                    sep='\t')
                    df_small = df[['Unnamed: 0', 'f1']].rename(columns={'Unnamed: 0': 'label'})


                # Keep only label + f1
                
                
                # Add task + seed + dataset info
                df_small['task'] = cond_parameters[0] if len(cond_parameters) > 0 else None
                df_small['seed'] = cond_parameters[-1] if cond_parameters[-1].isdigit() else None
                df_small['dataset'] = dataset
                df_small['method'] = method

                all_runs.append(df_small)
            except Exception as e:
                print(f"Skipping {folder_name} in {dataset}: {e}")

# Concatenate everything
results_all = pd.concat(all_runs, ignore_index=True)

# Convert numeric
results_all["f1"] = pd.to_numeric(results_all["f1"], errors="coerce")
# Drop Micro/Macro rows
results_all = results_all[~results_all["label"].str.contains("AVG")]

# display(results_all)

results_avg = (
    results_all
    .groupby(["dataset", "task", "label", "method"], as_index=False)["f1"]
    .mean()
)

# Save to new dataframe (already done, but here we keep both)
print("Original:", results_all.shape)
print("Averaged:", results_avg.shape)

# display(results_avg)
# Out:
# Original: (1800, 6)
# Averaged: (360, 5)

# %% [markdown]
# ### Micro-F1 for {POLARITY} Polarity (ACSA, avg over Methods & Seeds)

# %%
import matplotlib.pyplot as plt

category_map = {
    "essen": "FOOD",
    "service": "SERVICE",
    "gesamteindruck": "GENERAL",
    "ambiente": "AMBIENCE",
    "preis": "PRICE"
}



results_all[["category", "polarity"]] = results_all["label"].str.split(":", expand=True)
# Apply mapping
results_all["category"] = results_all["category"].replace(category_map)
acsa_only = results_all[results_all["task"].str.contains("acsa")]

# Average over seeds + datasets for each (method, category, polarity)
acsa_avg = (
    acsa_only
    .groupby(["dataset", "category", "polarity"], as_index=False)["f1"]
    .mean()
)

polarities = ["positive", "negative", "neutral"]
categories = ["essen", "service", "gesamteindruck", "ambiente", "preis"]

# --- Separate plots per polarity ---
for pol in polarities:
    df_plot = acsa_avg[acsa_avg["polarity"] == pol]

    plt.figure(figsize=(8, 5))
    for dataset in df_plot["dataset"].unique():
        subset = df_plot[df_plot["dataset"] == dataset]
        plt.plot(
            subset["category"], subset["f1"], marker="o", label=dataset
        )

    plt.title(f'Micro-F1 for {pol.capitalize()} Polarity averaged over Methods and Seeds (ACSA)')
    plt.xlabel("Category")
    plt.ylabel("Micro-F1")
    plt.ylim(0, 1)
    plt.legend(title="Dataset")
    plt.grid(True, linestyle="--", alpha=0.6)
    # plt.show()

# --- Subplots stacked vertically ---
fig, axes = plt.subplots(len(polarities), 1, figsize=(8, 15), sharex=True)

for i, pol in enumerate(polarities):
    ax = axes[i]
    df_plot = acsa_avg[acsa_avg["polarity"] == pol]

    for dataset in df_plot["dataset"].unique():
        subset = df_plot[df_plot["dataset"] == dataset]
        ax.plot(
            subset["category"], subset["f1"], marker="o", label=dataset,
        )

    ax.set_title(f'Micro-F1 for the {pol.capitalize()} Polarity (ACSA, avg over Methods & Seeds)')
    ax.set_ylabel("Micro-F1")
    ax.set_ylim(0, 1)
    ax.grid(True, linestyle="--", alpha=0.6)
    ax.legend(title="Dataset")

axes[-1].set_xlabel("Category")
plt.tight_layout()
plt.savefig("appendix_polarity_category_performance_acsa.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### STACKED: Micro-F1 for {pol.capitalize()} Polarity (ACSA, avg over Methods & Seeds)

# %%
plt.figure(figsize=(10, 6))
for pol in polarities:
    df_plot = acsa_avg[acsa_avg["polarity"] == pol]

    for dataset in df_plot["dataset"].unique():
        subset = df_plot[df_plot["dataset"] == dataset]
        plt.plot(
            subset["category"], subset["f1"], marker="o",
            label=f"{dataset} - {pol.capitalize()}"
        )

# plt.xlim(0, 5 * 1.1)
plt.title("Micro-F1 comparison across polarities (ACSA)")
plt.xlabel("Category")
plt.ylabel("Micro-F1")
plt.ylim(0, 1)
plt.legend(title="Dataset + Polarity", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Micro-F1 for {POLARITY} Polarity (ACSA, avg over DATASETS & Seeds)

# %%
import matplotlib.pyplot as plt


results_all[["category", "polarity"]] = results_all["label"].str.split(":", expand=True)
acsa_only = results_all[results_all["task"].str.contains("acsa") & 
                        results_all["dataset"].str.contains("Experts")]

# Average over seeds + datasets for each (method, category, polarity)
acsa_avg = (
    acsa_only
    .groupby(["method", "category", "polarity"], as_index=False)["f1"]
    .mean()
)

polarities = ["positive", "negative", "neutral"]
categories = ["essen", "service", "gesamteindruck", "ambiente", "preis"]

# --- Separate plots per polarity ---
for pol in polarities:
    df_plot = acsa_avg[acsa_avg["polarity"] == pol]

    plt.figure(figsize=(8, 5))
    for method in df_plot["method"].unique():
        subset = df_plot[df_plot["method"] == method]
        plt.plot(
            subset["category"], subset["f1"], marker="o", label=method
        )

    plt.title(f"ACSA task — Micro-F1 for {pol} polarity (averaged over methods)")
    plt.xlabel("Category")
    plt.ylabel("Micro-F1")
    plt.ylim(0, 1)
    plt.legend(title="Method")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

# %% [markdown]
# ### Micro-F1 for {POLARITY} Polarity (ACSA, avg over Methods & Datasets & Seeds)

# %%
plt.figure(figsize=(10, 6))
for pol in polarities:
    df_plot = acsa_avg[acsa_avg["polarity"] == pol]
    # average over datasets for cleaner polarity lines
    df_pol = df_plot.groupby(["category"], as_index=False)["f1"].mean()

    plt.plot(
        df_pol["category"], df_pol["f1"], marker="o", label=f"{pol} (avg over datasets)"
    )

plt.title("ACSA task — Micro-F1 comparison across polarities")
plt.xlabel("Category")
plt.ylabel("Micro-F1")
plt.ylim(0, 1)
plt.legend(title="Polarity")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# ### Micro-F1 for {CATEGORY} category (ACSA, avg over Methods & Seeds)

# %%
import matplotlib.pyplot as plt

polarities = ["positive", "negative", "neutral"]
categories = ["essen", "service", "gesamteindruck", "ambiente", "preis"]

# --- Separate plots per polarity ---
for cat in categories:
    df_plot = acsa_avg[acsa_avg["category"] == cat]

    plt.figure(figsize=(8, 5))
    for dataset in df_plot["dataset"].unique():
        subset = df_plot[df_plot["dataset"] == dataset]
        plt.plot(
            subset["polarity"], subset["f1"], marker="o", label=dataset
        )

    plt.title(f"ACSA task — Micro-F1 for {cat} category (averaged over methods)")
    plt.xlabel("polarity")
    plt.ylabel("Micro-F1")
    plt.ylim(0, 1)
    plt.legend(title="Dataset")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

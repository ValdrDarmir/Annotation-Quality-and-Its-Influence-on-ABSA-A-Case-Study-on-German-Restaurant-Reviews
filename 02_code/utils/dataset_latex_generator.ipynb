# %% [markdown]
# # TASD Overleaf Generator

# %%
import json

name_list = ["../../11_annotations/crowd/tasd/trainset_crowd_tasd_noconflict.jsonl",
             "../../11_annotations/students/tasd/trainset_students_tasd_noconflict.jsonl",
               "../../11_annotations/llm/tasd/tasd_llm_trainset_low.jsonl",
                "../../11_annotations/experts/tasd_experts_trainset_low.jsonl",
                "../../11_annotations/text_only/updatet_labels_original.jsonl"]

# ===== CONFIG =====
include_conflict = False  # <-- SWITCH: set False to remove Conflict column
categories = ['ambiente', 'essen', 'gesamteindruck', 'preis', 'service']
# ==================

# Define polarity order and labels
if include_conflict:
    polarities = ['positive', 'negative', 'neutral', 'conflict']
else:
    polarities = ['positive', 'negative', 'neutral']

for name in name_list:
    print(f"% ===== FILE: {name} ===== \n\n")
    file_name = name
    # Initialize stats
    stats = {cat: {pol: {'explicit': 0, 'implicit': 0}
                for pol in polarities} for cat in categories}

    # Read JSONL file
    with open(file_name, "r", encoding="utf-8") as f:
        for line in f:
            entry = json.loads(line)
            for cat, pol, phrase in entry["labels"]:
                # Map German to English polarities
                pol_map = {
                    'Positiv': 'Positive',
                    'Negativ': 'Negative',
                    'Neutral': 'Neutral',
                    'Konflikt': 'Conflict'
                }
                pol_eng = pol_map.get(pol, pol)
                if cat in stats and pol_eng in stats[cat]:
                    if phrase == "NULL":
                        stats[cat][pol_eng]['implicit'] += 1
                    else:
                        stats[cat][pol_eng]['explicit'] += 1

    # Prepare totals for each column
    col_totals = {pol: {'explicit': 0, 'implicit': 0} for pol in polarities}
    total_totals = {'explicit': 0, 'implicit': 0}

    # ===== LaTeX OUTPUT =====
    print(r"\begin{table}[h!]")
    print(r"\centering")
    print(
        r"\caption{Counts of polarity triplets by category, with explicit/implicit split}")
    print(r"\label{tab:triplet_counts}")

    # Define column alignment
    col_format = "l" + "cc" * len(polarities) + "cc"
    print(r"\begin{tabular}{" + col_format + "}")

    # First header row
    first_header = [" "]
    for pol in polarities:
        first_header.append(r"\multicolumn{2}{c}{\textbf{" + pol + "}}")
    first_header.append(r"\multicolumn{2}{c}{\textbf{Total}}")
    print(" & ".join(first_header) + r" \\ \hline")

    # Second header row
    second_header = [r"\textbf{Aspect Category}"]
    for _ in polarities + ["Total"]:
        second_header += [r"\textbf{Expl.}", r"\textbf{Impl.}"]
    print(" & ".join(second_header) + r"\\")
    print(r"\midrule")

    # Data rows
    for cat in categories:
        row = [cat]
        total_explicit = 0
        total_implicit = 0
        for pol in polarities:
            e = stats[cat][pol]['explicit']
            i = stats[cat][pol]['implicit']
            row += [str(e), str(i)]
            total_explicit += e
            total_implicit += i
            col_totals[pol]['explicit'] += e
            col_totals[pol]['implicit'] += i
        total_totals['explicit'] += total_explicit
        total_totals['implicit'] += total_implicit
        row += [str(total_explicit), str(total_implicit)]
        # print(" & ".join(row) + r" \\")
        print(",".join(row))

    # Totals row
    print(r"\hline")
    totals_row = [r"Total"]
    for pol in polarities:
        totals_row.append(str(col_totals[pol]['explicit']))
        totals_row.append(str(col_totals[pol]['implicit']))
    totals_row.append(str(total_totals['explicit']))
    totals_row.append(str(total_totals['implicit']))
    # print(" & ".join(totals_row) + r" \\")
    print(",".join(totals_row))
    print(r"\bottomrule")
    print(r"\end{tabular}")
    print(r"\end{table}")
    print("\n\n")
# Out:
# % ===== FILE: ../../11_annotations/crowd/tasd/trainset_crowd_tasd_noconflict.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente,81,3,26,8,0,0,107,11
# essen,232,19,134,26,21,3,387,48
# gesamteindruck,26,77,16,62,1,1,43,140
# preis,8,2,20,16,2,1,30,19
# service,128,10,79,34,3,1,210,45
# \hline
# Total,475,111,275,146,27,6,777,263
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/students/tasd/trainset_students_tasd_noconflict.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente,91,0,33,2,1,0,125,2
# essen,238,14,135,18,32,1,405,33
# gesamteindruck,35,74,13,67,1,0,49,141
# preis,14,0,28,10,5,0,47,10
# service,140,16,82,39,3,0,225,55
# \hline
# Total,518,104,291,136,42,1,851,241
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/llm/tasd/tasd_llm_trainset_low.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente,104,7,33,9,5,0,142,16
# essen,311,19,182,40,45,2,538,61
# gesamteindruck,5,122,3,98,0,9,8,229
# preis,19,1,30,12,6,0,55,13
# service,157,28,88,62,8,0,253,90
# \hline
# Total,596,177,336,221,64,11,996,409
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/experts/tasd_experts_trainset_low.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente,110,15,40,10,2,0,152,25
# essen,288,26,167,40,38,4,493,70
# gesamteindruck,33,103,17,90,2,5,52,198
# preis,15,1,42,12,6,0,63,13
# service,167,24,98,68,3,0,268,92
# \hline
# Total,613,169,364,220,51,9,1028,398
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/text_only/updatet_labels_original.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente,110,15,46,7,2,0,158,22
# essen,296,25,175,36,37,4,508,65
# gesamteindruck,33,99,17,89,3,6,53,194
# preis,16,1,42,12,6,0,64,13
# service,165,23,108,62,3,0,276,85
# \hline
# Total,620,163,388,206,51,10,1059,379
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # ACSA Overleaf Generator

# %%
import json

name_list = ["../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl",
             "../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl",
              "../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl",
               "../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl",
                "../../11_annotations/experts/acsa_experts_trainset_low.jsonl",
                "../../11_annotations/text_only/updatet_labels_original_acsa.jsonl"]


# ===== CONFIG =====
include_conflict = False  # <-- SWITCH: set True to keep "Conflict" column
categories = ['ambiente', 'essen', 'gesamteindruck', 'preis', 'service']
# ==================

# Define polarity order and labels
if include_conflict:
    polarities = ['positive', 'negative', 'neutral', 'conflict']
else:
    polarities = ['positive', 'negative', 'neutral']


for name in name_list:

    print(f"% ===== FILE: {name} =====\n\n")
    # Initialize stats
    stats = {cat: {pol: 0 for pol in polarities} for cat in categories}

    # Read JSONL file
    with open(name, "r", encoding="utf-8") as f:
        for line in f:
            entry = json.loads(line)
            for cat, pol in entry["labels"]:  # now only (category, polarity)
                pol_map = {
                    'Positiv': 'positive',
                    'Negativ': 'negative',
                    'Neutral': 'neutral',
                    'Konflikt': 'conflict'
                }
                pol_eng = pol_map.get(pol, pol.lower())
                if cat in stats and pol_eng in stats[cat]:
                    stats[cat][pol_eng] += 1

    # Prepare totals for each column
    col_totals = {pol: 0 for pol in polarities}
    total_total = 0

    # ===== LaTeX OUTPUT =====
    print(r"\begin{table}[h!]")
    print(r"\centering")
    print(r"\caption{Counts of polarity tuples by category}")
    print(r"\label{tab:tuple_counts}")

    # Define column alignment
    col_format = "l" + "c" * len(polarities) + "c"
    print(r"\begin{tabular}{" + col_format + "}")

    # Header row
    header = [r"\textbf{Aspect Category}"] + [r"\textbf{" + pol.capitalize() + "}" for pol in polarities] + [r"\textbf{Total}"]
    print(" & ".join(header) + r" \\ \hline")

    # Data rows
    for cat in categories:
        row = [cat]
        total = 0
        for pol in polarities:
            val = stats[cat][pol]
            row.append(str(val))
            total += val
            col_totals[pol] += val
        total_total += total
        row.append(str(total))
        print(" & ".join(row) + r" \\")
        print(",".join(row))

    # Totals row
    print(r"\hline")
    totals_row = [r"Total"] + [str(col_totals[pol]) for pol in polarities] + [str(total_total)]
    print(" & ".join(totals_row) + r" \\")
    print(",".join(totals_row))
    print(r"\bottomrule")
    print(r"\end{tabular}")
    print(r"\end{table}")
    print("\n\n")
# Out:
# % ===== FILE: ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 104 & 34 & 4 & 142 \\
# ambiente,104,34,4,142
# essen & 240 & 158 & 39 & 437 \\
# essen,240,158,39,437
# gesamteindruck & 157 & 120 & 16 & 293 \\
# gesamteindruck,157,120,16,293
# preis & 15 & 51 & 6 & 72 \\
# preis,15,51,6,72
# service & 174 & 161 & 3 & 338 \\
# service,174,161,3,338
# \hline
# Total & 690 & 524 & 68 & 1282 \\
# Total,690,524,68,1282
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 103 & 41 & 3 & 147 \\
# ambiente,103,41,3,147
# essen & 232 & 162 & 36 & 430 \\
# essen,232,162,36,430
# gesamteindruck & 151 & 119 & 9 & 279 \\
# gesamteindruck,151,119,9,279
# preis & 14 & 48 & 4 & 66 \\
# preis,14,48,4,66
# service & 176 & 155 & 4 & 335 \\
# service,176,155,4,335
# \hline
# Total & 676 & 525 & 56 & 1257 \\
# Total,676,525,56,1257
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 102 & 44 & 3 & 149 \\
# ambiente,102,44,3,149
# essen & 232 & 163 & 37 & 432 \\
# essen,232,163,37,432
# gesamteindruck & 164 & 130 & 12 & 306 \\
# gesamteindruck,164,130,12,306
# preis & 13 & 48 & 5 & 66 \\
# preis,13,48,5,66
# service & 175 & 156 & 4 & 335 \\
# service,175,156,4,335
# \hline
# Total & 686 & 541 & 61 & 1288 \\
# Total,686,541,61,1288
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 105 & 33 & 7 & 145 \\
# ambiente,105,33,7,145
# essen & 236 & 175 & 47 & 458 \\
# essen,236,175,47,458
# gesamteindruck & 146 & 116 & 10 & 272 \\
# gesamteindruck,146,116,10,272
# preis & 20 & 46 & 4 & 70 \\
# preis,20,46,4,70
# service & 163 & 145 & 7 & 315 \\
# service,163,145,7,315
# \hline
# Total & 670 & 515 & 75 & 1260 \\
# Total,670,515,75,1260
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/experts/acsa_experts_trainset_low.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 110 & 44 & 2 & 156 \\
# ambiente,110,44,2,156
# essen & 241 & 162 & 38 & 441 \\
# essen,241,162,38,441
# gesamteindruck & 135 & 107 & 7 & 249 \\
# gesamteindruck,135,107,7,249
# preis & 16 & 47 & 6 & 69 \\
# preis,16,47,6,69
# service & 172 & 154 & 3 & 329 \\
# service,172,154,3,329
# \hline
# Total & 674 & 514 & 56 & 1244 \\
# Total,674,514,56,1244
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== FILE: ../../11_annotations/text_only/updatet_labels_original_acsa.jsonl =====
#
#
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity tuples by category}
# \label{tab:tuple_counts}
# \begin{tabular}{lcccc}
# \textbf{Aspect Category} & \textbf{Positive} & \textbf{Negative} & \textbf{Neutral} & \textbf{Total} \\ \hline
# ambiente & 110 & 45 & 2 & 157 \\
# ambiente,110,45,2,157
# essen & 245 & 160 & 36 & 441 \\
# essen,245,160,36,441
# gesamteindruck & 131 & 106 & 9 & 246 \\
# gesamteindruck,131,106,9,246
# preis & 16 & 46 & 6 & 68 \\
# preis,16,46,6,68
# service & 169 & 158 & 3 & 330 \\
# service,169,158,3,330
# \hline
# Total & 671 & 515 & 56 & 1242 \\
# Total,671,515,56,1242
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # ACSA Checker
# - for Category or Polarity is different than predefined
# - Opposite Polarities

# %%
import json

# ===== CONFIG =====
name_list = [
    "../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl",
    "../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl",
    "../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl",
    "../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl",
    "../../11_annotations/experts/acsa_experts_trainset_low.jsonl",
    "../../11_annotations/ground_truth/acsa_testset_low.jsonl"
]

categories = ['ambiente', 'essen', 'gesamteindruck', 'preis', 'service']
polarities = ['positive', 'negative', 'neutral', 'conflict']
# ==================


def check_files(files):
    for file in files:
        print(f"\n=== Checking {file} ===")
        with open(file, "r", encoding="utf-8") as f:
            for line_no, line in enumerate(f, start=1):
                entry = json.loads(line)

                # skip entries with no labels
                if "labels" not in entry:
                    continue

                # collect all categories and polarities in this entry
                entry_cats = []
                entry_pols = []

                for label in entry["labels"]:
                    if len(label) < 2:
                        continue  # malformed
                    cat, pol = label[0], label[1]

                    # Check for invalid categories
                    if cat not in categories:
                        print(f"[Invalid Category] line {line_no}: {cat} in {file}")
                        print(line.strip())

                    # Normalize polarity for checking
                    pol_norm = pol.lower()

                    # Check for invalid polarities
                    if pol_norm not in polarities:
                        print(f"[Invalid Polarity] line {line_no}: {pol} in {file}")
                        print(line.strip())

                    # Check for any 'conflict' variants
                    if pol_norm == "conflict" or pol.lower() in ["konflikt", "Konflikt"]:
                        print(f"[Conflict Found] line {line_no}: {pol} in {file}")
                        print(line.strip())

                    entry_cats.append(cat)
                    entry_pols.append(pol_norm)

                # Check for opposite polarities within same text
                if "positive" in entry_pols and "negative" in entry_pols:
                    print(f"[Opposite Polarities] line {line_no} in {file}")
                    print(line.strip())

# Run checks
check_files(name_list)
# Out:
# === Checking ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl ===
# [Opposite Polarities] line 47 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "46", "original_id": "109", "text": "Der georderte vegane Bagel war köstlich was wir von den lieblos angerichteten Käsespätzle leider nicht behaupten konnten.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 69 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "68", "original_id": "170", "text": "Vom Ambiente her natürlich toll, RESTAURANT_NAME eben, alles sehr sauber...aber der Empfang war mehr als unfreundlich, der Kellner am Tisch dafür wieder sehr aber nachdem wir von zwei servicekräften sehr unfreundlich begrüßt wurden wären wir fast wieder gegangen, essen war dann leider auch nicht toll, die Burger,waren sehr trocken, würden nicht nochmal wieder kommen...leider", "labels": [["ambiente", "positive"], ["service", "positive"], ["essen", "negative"], ["service", "negative"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 192 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "191", "original_id": "408", "text": "Das ambiente und der Anfang waren gut, leider kann ich den Cesarsalat ohne dressing nicht weiterempfehlen, der Hauptgang war gut wie auch das dessert , kann aber für weniger Geld im LOC besser Essen, Preis Leistung hätte noch Potenzial.", "labels": [["ambiente", "positive"], ["essen", "negative"], ["preis", "negative"]]}
# [Opposite Polarities] line 225 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "224", "original_id": "465", "text": "Leider war der Hauptgang Rinderfilet so zäh und durchwachsen dass dies den guten Gesamteindruck nachhaltig beschädigt hat.", "labels": [["gesamteindruck", "positive"], ["gesamteindruck", "negative"], ["essen", "negative"]]}
# [Opposite Polarities] line 261 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "260", "original_id": "543", "text": "Sehr gute Scampi, aber eben nur die.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 304 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "303", "original_id": "619", "text": "Essen topp und Service auch, nur einen unmöglichen Kellner dabei, der mit den Tunneln im Ohr, der seine Kollegin ständig laut anpöbelt vor den Gäste, dass sie zu langsam sind und dich bewegen sollen usw.", "labels": [["service", "positive"], ["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 305 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "304", "original_id": "620", "text": "Früher hat man das antiquierte Ambiente nicht beachtet, weil die Steaks sehr gut waren.", "labels": [["ambiente", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 306 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "305", "original_id": "621", "text": "Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .", "labels": [["ambiente", "positive"], ["service", "negative"], ["gesamteindruck", "negative"], ["preis", "negative"]]}
# [Opposite Polarities] line 374 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "373", "original_id": "785", "text": "Gutes Bier zum günstigen Preis Halbe 3,95 aber kleine BierkarteAugustiner Schmakerl mit moderaten Preis.", "labels": [["preis", "neutral"], ["preis", "positive"], ["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 379 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "378", "original_id": "798", "text": "Alles in allem: schneller Service, gutes Essen, Getränke zu teuer und am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch", "labels": [["service", "positive"], ["preis", "negative"], ["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 404 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "403", "original_id": "859", "text": "Essen war wie immer top, jedoch bei den LOC habe ich den Ziegenkäsegeschmack des Ziegenkäses vermisst.", "labels": [["gesamteindruck", "positive"], ["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 421 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "420", "original_id": "903", "text": "Wir waren mittags hier, das Ambiente ist top und auch das Bier ist super, leider sind die Speisen \"nur\" Ok.", "labels": [["ambiente", "positive"], ["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 454 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "453", "original_id": "974", "text": "Das Schnitzel war das Fleisch gut jedoch weder Fleisch noch Panade gesalzen und Gewürzt nach würzen bringt es nicht die Bratkartoffeln auch beim Tagesgericht verdienen das Wort nicht nur wenige waren gebraten alle anderen offensichtlich in noch nich erhitzten Fett oder Öl warm gemacht dadurch haben sie sich vollgesogen so was darf man nicht servieren den Kellnern den wir das dagegen interessieren sich nicht", "labels": [["service", "negative"], ["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 503 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "502", "original_id": "1075", "text": "Wie gesagt, es war alles super lecker, aber wir haben in besseren Restaurants in LOC gegessen und einen ähnlichen oder sogar günstigeren Preis bezahlt.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 558 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "557", "original_id": "1190", "text": "Nach dem Hinweis dazu an die ansonsten sehr aufmerksame Servicekraft wurde lediglich ein Hinweis an die Küche entgegnet.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 560 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "559", "original_id": "1194", "text": "Das Essen war bei mir sehr gut aber mein Sohn hatte ein kaltes lauwarmes hähnchen und der Rest war einfach nur kalt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 573 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "572", "original_id": "1231", "text": "Haben lecker gegessen....Fisch... Steak...alles geschmacklich gut.... leider ist das Küchenpersonal wohl etwas unfähig...wurden von der Bedienung informiert, dass Vorspeise gleichzeitig mit Hauptspeise gereicht wird, ( beim Alex im Hafen war es besser)....auch was knusprige Bratkartoffeln sind weiß das Küchenpersonal hier wohl nicht, bzw kennt sich mit der eigenen Karte wohl nicht aus.", "labels": [["service", "negative"], ["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 574 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "573", "original_id": "1233", "text": "Da wir kein Tisch reserviert haben , würden wir nicht so gerne aufgenommen und wurde nur ne Stunde Zeit gegeben zum Essen …schade sonst war das Essen sehr lecker", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 587 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "586", "original_id": "1272", "text": "Das Essen meiner Frau war sehr lecker, mein Fleisch war leider etwas fettig.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 590 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "589", "original_id": "1281", "text": "Zugegeben das Filet war sehr gut, aber das war auch schon das Beste an dem ganzen Abend.", "labels": [["gesamteindruck", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 598 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "597", "original_id": "1298", "text": "Einzig der Wein war seinen Preis wert.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 616 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "615", "original_id": "1334", "text": "Das Essen ist zwar etwas teurer als sonst beim LOC, aber auch um mindestens 2 Klassen besser.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 618 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "617", "original_id": "1340", "text": "Wie immer super qualifizierter Service, leider kam heute die Küche nicht so pünktlich wie sonst immer hinterher.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 666 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "665", "original_id": "1452", "text": "Ich bin gerne hier.. ein großer Minus Punkt ist, dass die die Tische nicht abgeräumt werden.", "labels": [["gesamteindruck", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 669 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "668", "original_id": "1455", "text": "Wir wollten uns zum Hochzeitstag mal was besonderes gönnen , doch sind wir beide sehr entäuscht worden , das Schnitzel war nicht nur schlabberig sondern auch ungewürzt , die Jägersoße war auch nicht besser , ein kleiner Salat sollte eigentlich zu jedem Gericht gehören , einzig die Bedienung war freundlich .", "labels": [["service", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 685 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "684", "original_id": "1488", "text": "Essen lieblos hergerichtet, Ambiente toll, Service gestresst und hat mir die Freude auf diesen Abend genommen.", "labels": [["ambiente", "positive"], ["service", "negative"], ["essen", "negative"]]}
# [Opposite Polarities] line 749 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "748", "original_id": "1614", "text": "Essen lecker, jedoch überteuert.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 779 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "778", "original_id": "1673", "text": "Wie schon oben beschrieben kann man hier nett sitzen, zum essen würde ich lieber beim nächsten Besuch in LOC ein anderes Restaurant besuchen.", "labels": [["ambiente", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 793 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "792", "original_id": "1717", "text": "Auf ein zwei schöne Biere kommen wir sicher wieder, essen werden wir vermutlich nicht mehr.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 823 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "822", "original_id": "1783", "text": "Fränkische Bratwürste, die waren gut, aber das Sauerkraut dazu hat nach gar nichts geschmeckt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 854 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "853", "original_id": "1838", "text": "Carpaccio ein Traum 😍 Leider war bei einem Steak der Gargrad falsch, darf eigentlich nicht passieren in so einem Haus.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 858 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "857", "original_id": "1846", "text": "Auch wenn das Ambiente nicht so ansprechend war, hat uns doch das Konzept und die Frische der Speisen überzeugt.", "labels": [["gesamteindruck", "positive"], ["ambiente", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 864 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "863", "original_id": "1857", "text": "Die Vorspeise war per sè schön angerichtet und hat auch geschmeckt.... bekamen was anderes als Burrata wegen laktose, danach ging leider der Tiefflug, angehend von der Karte, in einen Sturzflug über.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 865 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "864", "original_id": "1859", "text": "Mein Fazit: Aufgrund der Essensqualität würde ich dem Brauhaus noch eine Chance geben (darum auch drei Sterne), aber an der Servicequalität muss definitiv schwer gearbeitet werden.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 879 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "878", "original_id": "1882", "text": "Man kann gerne zum Wagner weil es eine urige Kneipe ist, LOC sollte man aber nicht unbedingt.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 957 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "956", "original_id": "2058", "text": "das spätere essen (Pizza) war wirklich gut, aber so viel Zeit während der Woche haben wir nicht und werden deshalb auch nicht wieder kommen.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 960 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "959", "original_id": "2067", "text": "Ich habe dort keine schöne Erfahrung gemacht, dabei ist das Ambiente äußerst angenehm.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 969 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "968", "original_id": "2085", "text": "Atmosphäre des Lokals ist gut, Personal reagierte auf den Wunsch, beim Salat eine Zutat wegzulassen allerdings unflexibel und der Inhaber ist mehr als unfreundlich.", "labels": [["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 977 in ../../11_annotations/crowd/acsa/trainset_crowd_acsa_noconflict.jsonl
# {"id": "976", "original_id": "2106", "text": "Beim Schweinebraten hat die Würze gefehlt, der dazugehörige Salat war fantastisch, die Kruste auch, der Kartoffelknödel war essbar, der Semmelknödel weniger.", "labels": [["essen", "negative"], ["essen", "neutral"], ["essen", "positive"]]}
#
# === Checking ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl ===
# [Opposite Polarities] line 47 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "46", "original_id": "109", "text": "Der georderte vegane Bagel war köstlich was wir von den lieblos angerichteten Käsespätzle leider nicht behaupten konnten.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 69 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "68", "original_id": "170", "text": "Vom Ambiente her natürlich toll, RESTAURANT_NAME eben, alles sehr sauber...aber der Empfang war mehr als unfreundlich, der Kellner am Tisch dafür wieder sehr aber nachdem wir von zwei servicekräften sehr unfreundlich begrüßt wurden wären wir fast wieder gegangen, essen war dann leider auch nicht toll, die Burger,waren sehr trocken, würden nicht nochmal wieder kommen...leider", "labels": [["essen", "negative"], ["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 82 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "81", "original_id": "194", "text": "Tapas waren für uns nichts besonderes, haben wir auch in LOC schon viel besser/geschmacklich interessanter gehabt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 90 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "89", "original_id": "210", "text": "Die Portionen waren sehr gross und eigentlich zu viel für uns älteren Leute.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 106 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "105", "original_id": "244", "text": "Es ist nicht in Ordnung in so einem historischen Ort und unzulässig gegenüber den Gästen!", "labels": [["service", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 143 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "142", "original_id": "310", "text": "Schade, da die Aussicht super wäre.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 192 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "191", "original_id": "408", "text": "Das ambiente und der Anfang waren gut, leider kann ich den Cesarsalat ohne dressing nicht weiterempfehlen, der Hauptgang war gut wie auch das dessert , kann aber für weniger Geld im LOC besser Essen, Preis Leistung hätte noch Potenzial.", "labels": [["essen", "negative"], ["preis", "negative"], ["ambiente", "positive"], ["essen", "positive"]]}
# [Opposite Polarities] line 225 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "224", "original_id": "465", "text": "Leider war der Hauptgang Rinderfilet so zäh und durchwachsen dass dies den guten Gesamteindruck nachhaltig beschädigt hat.", "labels": [["essen", "negative"], ["gesamteindruck", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 248 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "247", "original_id": "518", "text": "Der Auslieferungsfahrer war sehr nett und hat sich entschuldigt.", "labels": [["service", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 253 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "252", "original_id": "527", "text": "Die Lage des Lokals am LOC ist perfekt, die Keller-Räumlichkeiten sind gemütlich - da kommen die Kunden sowieso, da braucht man sich wohl keine Mühe zu geben.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 261 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "260", "original_id": "543", "text": "Sehr gute Scampi, aber eben nur die.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 304 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "303", "original_id": "619", "text": "Essen topp und Service auch, nur einen unmöglichen Kellner dabei, der mit den Tunneln im Ohr, der seine Kollegin ständig laut anpöbelt vor den Gäste, dass sie zu langsam sind und dich bewegen sollen usw.", "labels": [["service", "negative"], ["essen", "positive"], ["service", "positive"]]}
# [Opposite Polarities] line 305 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "304", "original_id": "620", "text": "Früher hat man das antiquierte Ambiente nicht beachtet, weil die Steaks sehr gut waren.", "labels": [["essen", "positive"], ["ambiente", "negative"]]}
# [Opposite Polarities] line 306 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "305", "original_id": "621", "text": "Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .", "labels": [["preis", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 379 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "378", "original_id": "798", "text": "Alles in allem: schneller Service, gutes Essen, Getränke zu teuer und am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch", "labels": [["preis", "negative"], ["essen", "positive"], ["service", "positive"]]}
# [Opposite Polarities] line 404 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "403", "original_id": "859", "text": "Essen war wie immer top, jedoch bei den LOC habe ich den Ziegenkäsegeschmack des Ziegenkäses vermisst.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 454 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "453", "original_id": "974", "text": "Das Schnitzel war das Fleisch gut jedoch weder Fleisch noch Panade gesalzen und Gewürzt nach würzen bringt es nicht die Bratkartoffeln auch beim Tagesgericht verdienen das Wort nicht nur wenige waren gebraten alle anderen offensichtlich in noch nich erhitzten Fett oder Öl warm gemacht dadurch haben sie sich vollgesogen so was darf man nicht servieren den Kellnern den wir das dagegen interessieren sich nicht", "labels": [["service", "negative"], ["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 503 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "502", "original_id": "1075", "text": "Wie gesagt, es war alles super lecker, aber wir haben in besseren Restaurants in LOC gegessen und einen ähnlichen oder sogar günstigeren Preis bezahlt.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 558 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "557", "original_id": "1190", "text": "Nach dem Hinweis dazu an die ansonsten sehr aufmerksame Servicekraft wurde lediglich ein Hinweis an die Küche entgegnet.", "labels": [["service", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 560 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "559", "original_id": "1194", "text": "Das Essen war bei mir sehr gut aber mein Sohn hatte ein kaltes lauwarmes hähnchen und der Rest war einfach nur kalt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 573 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "572", "original_id": "1231", "text": "Haben lecker gegessen....Fisch... Steak...alles geschmacklich gut.... leider ist das Küchenpersonal wohl etwas unfähig...wurden von der Bedienung informiert, dass Vorspeise gleichzeitig mit Hauptspeise gereicht wird, ( beim Alex im Hafen war es besser)....auch was knusprige Bratkartoffeln sind weiß das Küchenpersonal hier wohl nicht, bzw kennt sich mit der eigenen Karte wohl nicht aus.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 574 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "573", "original_id": "1233", "text": "Da wir kein Tisch reserviert haben , würden wir nicht so gerne aufgenommen und wurde nur ne Stunde Zeit gegeben zum Essen …schade sonst war das Essen sehr lecker", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 586 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "585", "original_id": "1271", "text": "Man zahlt zwar etwas mehr, der Service, die nette Bedienung und die Atmosphäre sind es wert!", "labels": [["preis", "negative"], ["ambiente", "positive"], ["service", "positive"]]}
# [Opposite Polarities] line 587 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "586", "original_id": "1272", "text": "Das Essen meiner Frau war sehr lecker, mein Fleisch war leider etwas fettig.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 590 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "589", "original_id": "1281", "text": "Zugegeben das Filet war sehr gut, aber das war auch schon das Beste an dem ganzen Abend.", "labels": [["gesamteindruck", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 616 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "615", "original_id": "1334", "text": "Das Essen ist zwar etwas teurer als sonst beim LOC, aber auch um mindestens 2 Klassen besser.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 669 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "668", "original_id": "1455", "text": "Wir wollten uns zum Hochzeitstag mal was besonderes gönnen , doch sind wir beide sehr entäuscht worden , das Schnitzel war nicht nur schlabberig sondern auch ungewürzt , die Jägersoße war auch nicht besser , ein kleiner Salat sollte eigentlich zu jedem Gericht gehören , einzig die Bedienung war freundlich .", "labels": [["essen", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 685 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "684", "original_id": "1488", "text": "Essen lieblos hergerichtet, Ambiente toll, Service gestresst und hat mir die Freude auf diesen Abend genommen.", "labels": [["service", "negative"], ["essen", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 749 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "748", "original_id": "1614", "text": "Essen lecker, jedoch überteuert.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 779 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "778", "original_id": "1673", "text": "Wie schon oben beschrieben kann man hier nett sitzen, zum essen würde ich lieber beim nächsten Besuch in LOC ein anderes Restaurant besuchen.", "labels": [["essen", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 793 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "792", "original_id": "1717", "text": "Auf ein zwei schöne Biere kommen wir sicher wieder, essen werden wir vermutlich nicht mehr.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 823 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "822", "original_id": "1783", "text": "Fränkische Bratwürste, die waren gut, aber das Sauerkraut dazu hat nach gar nichts geschmeckt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 854 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "853", "original_id": "1838", "text": "Carpaccio ein Traum 😍 Leider war bei einem Steak der Gargrad falsch, darf eigentlich nicht passieren in so einem Haus.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 858 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "857", "original_id": "1846", "text": "Auch wenn das Ambiente nicht so ansprechend war, hat uns doch das Konzept und die Frische der Speisen überzeugt.", "labels": [["essen", "positive"], ["ambiente", "negative"]]}
# [Opposite Polarities] line 864 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "863", "original_id": "1857", "text": "Die Vorspeise war per sè schön angerichtet und hat auch geschmeckt.... bekamen was anderes als Burrata wegen laktose, danach ging leider der Tiefflug, angehend von der Karte, in einen Sturzflug über.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 865 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "864", "original_id": "1859", "text": "Mein Fazit: Aufgrund der Essensqualität würde ich dem Brauhaus noch eine Chance geben (darum auch drei Sterne), aber an der Servicequalität muss definitiv schwer gearbeitet werden.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 957 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "956", "original_id": "2058", "text": "das spätere essen (Pizza) war wirklich gut, aber so viel Zeit während der Woche haben wir nicht und werden deshalb auch nicht wieder kommen.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 960 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "959", "original_id": "2067", "text": "Ich habe dort keine schöne Erfahrung gemacht, dabei ist das Ambiente äußerst angenehm.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 969 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "968", "original_id": "2085", "text": "Atmosphäre des Lokals ist gut, Personal reagierte auf den Wunsch, beim Salat eine Zutat wegzulassen allerdings unflexibel und der Inhaber ist mehr als unfreundlich.", "labels": [["service", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 977 in ../../11_annotations/students/acsa/trainset_students_acsa_noconflict.jsonl
# {"id": "976", "original_id": "2106", "text": "Beim Schweinebraten hat die Würze gefehlt, der dazugehörige Salat war fantastisch, die Kruste auch, der Kartoffelknödel war essbar, der Semmelknödel weniger.", "labels": [["essen", "negative"], ["essen", "neutral"], ["essen", "positive"]]}
#
# === Checking ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl ===
# [Opposite Polarities] line 47 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "46", "original_id": "109", "text": "Der georderte vegane Bagel war köstlich was wir von den lieblos angerichteten Käsespätzle leider nicht behaupten konnten.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 69 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "68", "original_id": "170", "text": "Vom Ambiente her natürlich toll, RESTAURANT_NAME eben, alles sehr sauber...aber der Empfang war mehr als unfreundlich, der Kellner am Tisch dafür wieder sehr aber nachdem wir von zwei servicekräften sehr unfreundlich begrüßt wurden wären wir fast wieder gegangen, essen war dann leider auch nicht toll, die Burger,waren sehr trocken, würden nicht nochmal wieder kommen...leider", "labels": [["ambiente", "positive"], ["essen", "negative"], ["service", "negative"]]}
# [Opposite Polarities] line 82 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "81", "original_id": "194", "text": "Tapas waren für uns nichts besonderes, haben wir auch in LOC schon viel besser/geschmacklich interessanter gehabt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 90 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "89", "original_id": "210", "text": "Die Portionen waren sehr gross und eigentlich zu viel für uns älteren Leute.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 106 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "105", "original_id": "244", "text": "Es ist nicht in Ordnung in so einem historischen Ort und unzulässig gegenüber den Gästen!", "labels": [["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 143 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "142", "original_id": "310", "text": "Schade, da die Aussicht super wäre.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 192 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "191", "original_id": "408", "text": "Das ambiente und der Anfang waren gut, leider kann ich den Cesarsalat ohne dressing nicht weiterempfehlen, der Hauptgang war gut wie auch das dessert , kann aber für weniger Geld im LOC besser Essen, Preis Leistung hätte noch Potenzial.", "labels": [["ambiente", "positive"], ["essen", "negative"], ["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 225 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "224", "original_id": "465", "text": "Leider war der Hauptgang Rinderfilet so zäh und durchwachsen dass dies den guten Gesamteindruck nachhaltig beschädigt hat.", "labels": [["gesamteindruck", "negative"], ["essen", "negative"], ["gesamteindruck", "positive"]]}
# [Opposite Polarities] line 248 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "247", "original_id": "518", "text": "Der Auslieferungsfahrer war sehr nett und hat sich entschuldigt.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 253 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "252", "original_id": "527", "text": "Die Lage des Lokals am LOC ist perfekt, die Keller-Räumlichkeiten sind gemütlich - da kommen die Kunden sowieso, da braucht man sich wohl keine Mühe zu geben.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 261 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "260", "original_id": "543", "text": "Sehr gute Scampi, aber eben nur die.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 304 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "303", "original_id": "619", "text": "Essen topp und Service auch, nur einen unmöglichen Kellner dabei, der mit den Tunneln im Ohr, der seine Kollegin ständig laut anpöbelt vor den Gäste, dass sie zu langsam sind und dich bewegen sollen usw.", "labels": [["service", "positive"], ["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 305 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "304", "original_id": "620", "text": "Früher hat man das antiquierte Ambiente nicht beachtet, weil die Steaks sehr gut waren.", "labels": [["essen", "positive"], ["ambiente", "negative"]]}
# [Opposite Polarities] line 306 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "305", "original_id": "621", "text": "Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .", "labels": [["ambiente", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 379 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "378", "original_id": "798", "text": "Alles in allem: schneller Service, gutes Essen, Getränke zu teuer und am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch", "labels": [["service", "positive"], ["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 503 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "502", "original_id": "1075", "text": "Wie gesagt, es war alles super lecker, aber wir haben in besseren Restaurants in LOC gegessen und einen ähnlichen oder sogar günstigeren Preis bezahlt.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 573 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "572", "original_id": "1231", "text": "Haben lecker gegessen....Fisch... Steak...alles geschmacklich gut.... leider ist das Küchenpersonal wohl etwas unfähig...wurden von der Bedienung informiert, dass Vorspeise gleichzeitig mit Hauptspeise gereicht wird, ( beim Alex im Hafen war es besser)....auch was knusprige Bratkartoffeln sind weiß das Küchenpersonal hier wohl nicht, bzw kennt sich mit der eigenen Karte wohl nicht aus.", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 574 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "573", "original_id": "1233", "text": "Da wir kein Tisch reserviert haben , würden wir nicht so gerne aufgenommen und wurde nur ne Stunde Zeit gegeben zum Essen …schade sonst war das Essen sehr lecker", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 590 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "589", "original_id": "1281", "text": "Zugegeben das Filet war sehr gut, aber das war auch schon das Beste an dem ganzen Abend.", "labels": [["essen", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 616 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "615", "original_id": "1334", "text": "Das Essen ist zwar etwas teurer als sonst beim LOC, aber auch um mindestens 2 Klassen besser.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 618 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "617", "original_id": "1340", "text": "Wie immer super qualifizierter Service, leider kam heute die Küche nicht so pünktlich wie sonst immer hinterher.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 666 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "665", "original_id": "1452", "text": "Ich bin gerne hier.. ein großer Minus Punkt ist, dass die die Tische nicht abgeräumt werden.", "labels": [["gesamteindruck", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 669 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "668", "original_id": "1455", "text": "Wir wollten uns zum Hochzeitstag mal was besonderes gönnen , doch sind wir beide sehr entäuscht worden , das Schnitzel war nicht nur schlabberig sondern auch ungewürzt , die Jägersoße war auch nicht besser , ein kleiner Salat sollte eigentlich zu jedem Gericht gehören , einzig die Bedienung war freundlich .", "labels": [["essen", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 685 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "684", "original_id": "1488", "text": "Essen lieblos hergerichtet, Ambiente toll, Service gestresst und hat mir die Freude auf diesen Abend genommen.", "labels": [["ambiente", "positive"], ["essen", "negative"], ["gesamteindruck", "negative"], ["service", "negative"]]}
# [Opposite Polarities] line 714 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "713", "original_id": "1553", "text": "Vergangene Weihnachten dort gewesen,unvergesslicher Heiligabend,-und jetzt?", "labels": [["gesamteindruck", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 749 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "748", "original_id": "1614", "text": "Essen lecker, jedoch überteuert.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 779 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "778", "original_id": "1673", "text": "Wie schon oben beschrieben kann man hier nett sitzen, zum essen würde ich lieber beim nächsten Besuch in LOC ein anderes Restaurant besuchen.", "labels": [["ambiente", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 793 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "792", "original_id": "1717", "text": "Auf ein zwei schöne Biere kommen wir sicher wieder, essen werden wir vermutlich nicht mehr.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 823 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "822", "original_id": "1783", "text": "Fränkische Bratwürste, die waren gut, aber das Sauerkraut dazu hat nach gar nichts geschmeckt.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 854 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "853", "original_id": "1838", "text": "Carpaccio ein Traum 😍 Leider war bei einem Steak der Gargrad falsch, darf eigentlich nicht passieren in so einem Haus.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 858 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "857", "original_id": "1846", "text": "Auch wenn das Ambiente nicht so ansprechend war, hat uns doch das Konzept und die Frische der Speisen überzeugt.", "labels": [["essen", "positive"], ["ambiente", "negative"]]}
# [Opposite Polarities] line 864 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "863", "original_id": "1857", "text": "Die Vorspeise war per sè schön angerichtet und hat auch geschmeckt.... bekamen was anderes als Burrata wegen laktose, danach ging leider der Tiefflug, angehend von der Karte, in einen Sturzflug über.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 865 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "864", "original_id": "1859", "text": "Mein Fazit: Aufgrund der Essensqualität würde ich dem Brauhaus noch eine Chance geben (darum auch drei Sterne), aber an der Servicequalität muss definitiv schwer gearbeitet werden.", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 957 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "956", "original_id": "2058", "text": "das spätere essen (Pizza) war wirklich gut, aber so viel Zeit während der Woche haben wir nicht und werden deshalb auch nicht wieder kommen.", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 960 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "959", "original_id": "2067", "text": "Ich habe dort keine schöne Erfahrung gemacht, dabei ist das Ambiente äußerst angenehm.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 969 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "968", "original_id": "2085", "text": "Atmosphäre des Lokals ist gut, Personal reagierte auf den Wunsch, beim Salat eine Zutat wegzulassen allerdings unflexibel und der Inhaber ist mehr als unfreundlich.", "labels": [["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 977 in ../../11_annotations/students/acsa/trainset_students_acsa_redo_noconflict.jsonl
# {"id": "976", "original_id": "2106", "text": "Beim Schweinebraten hat die Würze gefehlt, der dazugehörige Salat war fantastisch, die Kruste auch, der Kartoffelknödel war essbar, der Semmelknödel weniger.", "labels": [["essen", "neutral"], ["essen", "negative"], ["essen", "positive"]]}
#
# === Checking ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl ===
# [Opposite Polarities] line 47 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "46", "original_id": "109", "text": "Der georderte vegane Bagel war köstlich was wir von den lieblos angerichteten Käsespätzle leider nicht behaupten konnten.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 69 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "68", "original_id": "170", "text": "Vom Ambiente her natürlich toll, RESTAURANT_NAME eben, alles sehr sauber...aber der Empfang war mehr als unfreundlich, der Kellner am Tisch dafür wieder sehr aber nachdem wir von zwei servicekräften sehr unfreundlich begrüßt wurden wären wir fast wieder gegangen, essen war dann leider auch nicht toll, die Burger,waren sehr trocken, würden nicht nochmal wieder kommen...leider", "labels": [["gesamteindruck", "negative"], ["essen", "negative"], ["service", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 192 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "191", "original_id": "408", "text": "Das ambiente und der Anfang waren gut, leider kann ich den Cesarsalat ohne dressing nicht weiterempfehlen, der Hauptgang war gut wie auch das dessert , kann aber für weniger Geld im LOC besser Essen, Preis Leistung hätte noch Potenzial.", "labels": [["essen", "positive"], ["preis", "negative"], ["essen", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 304 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "303", "original_id": "619", "text": "Essen topp und Service auch, nur einen unmöglichen Kellner dabei, der mit den Tunneln im Ohr, der seine Kollegin ständig laut anpöbelt vor den Gäste, dass sie zu langsam sind und dich bewegen sollen usw.", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 306 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "305", "original_id": "621", "text": "Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .", "labels": [["essen", "negative"], ["service", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 379 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "378", "original_id": "798", "text": "Alles in allem: schneller Service, gutes Essen, Getränke zu teuer und am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch", "labels": [["preis", "negative"], ["service", "positive"], ["essen", "positive"]]}
# [Opposite Polarities] line 404 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "403", "original_id": "859", "text": "Essen war wie immer top, jedoch bei den LOC habe ich den Ziegenkäsegeschmack des Ziegenkäses vermisst.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 458 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "457", "original_id": "985", "text": "Richtig schön, waren die Blumenblätter auf den Gerichten, aber das war leider auch schon alles.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 503 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "502", "original_id": "1075", "text": "Wie gesagt, es war alles super lecker, aber wir haben in besseren Restaurants in LOC gegessen und einen ähnlichen oder sogar günstigeren Preis bezahlt.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 558 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "557", "original_id": "1190", "text": "Nach dem Hinweis dazu an die ansonsten sehr aufmerksame Servicekraft wurde lediglich ein Hinweis an die Küche entgegnet.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 560 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "559", "original_id": "1194", "text": "Das Essen war bei mir sehr gut aber mein Sohn hatte ein kaltes lauwarmes hähnchen und der Rest war einfach nur kalt.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 573 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# {"id": "572", "original_id": "1231", "text": "Haben lecker gegessen....Fisch... Steak...alles geschmacklich gut.... leider ist das Küchenpersonal wohl etwas unfähig...wurden von der Bedienung informiert, dass Vorspeise gleichzeitig mit Hauptspeise gereicht wird, ( beim Alex im Hafen war es besser)....auch was knusprige Bratkartoffeln sind weiß das Küchenpersonal hier wohl nicht, bzw kennt sich mit der eigenen Karte wohl nicht aus.", "labels": [["essen", "negative"], ["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 574 in ../../11_annotations/llm/acsa/acsa_llm_trainset_low.jsonl
# ...
# [Opposite Polarities] line 586 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "586", "original_id": "1271", "text": "Man zahlt zwar etwas mehr, der Service, die nette Bedienung und die Atmosphäre sind es wert!", "labels": [["preis", "negative"], ["service", "positive"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 587 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "587", "original_id": "1272", "text": "Das Essen meiner Frau war sehr lecker, mein Fleisch war leider etwas fettig.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 590 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "590", "original_id": "1281", "text": "Zugegeben das Filet war sehr gut, aber das war auch schon das Beste an dem ganzen Abend.", "labels": [["essen", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 616 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "616", "original_id": "1334", "text": "Das Essen ist zwar etwas teurer als sonst beim LOC, aber auch um mindestens 2 Klassen besser.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 618 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "618", "original_id": "1340", "text": "Wie immer super qualifizierter Service, leider kam heute die Küche nicht so pünktlich wie sonst immer hinterher.", "labels": [["service", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 666 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "666", "original_id": "1452", "text": "Ich bin gerne hier.. ein großer Minus Punkt ist, dass die die Tische nicht abgeräumt werden.", "labels": [["service", "negative"], ["gesamteindruck", "positive"]]}
# [Opposite Polarities] line 669 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "669", "original_id": "1455", "text": "Wir wollten uns zum Hochzeitstag mal was besonderes gönnen , doch sind wir beide sehr entäuscht worden , das Schnitzel war nicht nur schlabberig sondern auch ungewürzt , die Jägersoße war auch nicht besser , ein kleiner Salat sollte eigentlich zu jedem Gericht gehören , einzig die Bedienung war freundlich .", "labels": [["essen", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 685 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "685", "original_id": "1488", "text": "Essen lieblos hergerichtet, Ambiente toll, Service gestresst und hat mir die Freude auf diesen Abend genommen.", "labels": [["essen", "negative"], ["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 723 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "723", "original_id": "1571", "text": "LOC mit abwechslungsreichen Speiseangebot, der Service ist eingedeutscht.", "labels": [["service", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 749 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "749", "original_id": "1614", "text": "Essen lecker, jedoch überteuert.", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 779 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "779", "original_id": "1673", "text": "Wie schon oben beschrieben kann man hier nett sitzen, zum essen würde ich lieber beim nächsten Besuch in LOC ein anderes Restaurant besuchen.", "labels": [["ambiente", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 793 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "793", "original_id": "1717", "text": "Auf ein zwei schöne Biere kommen wir sicher wieder, essen werden wir vermutlich nicht mehr.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 823 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "823", "original_id": "1783", "text": "Fränkische Bratwürste, die waren gut, aber das Sauerkraut dazu hat nach gar nichts geschmeckt.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 852 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "852", "original_id": "1836", "text": "Schnelle Küche mit geringem Anspruch.", "labels": [["service", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 854 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "854", "original_id": "1838", "text": "Carpaccio ein Traum 😍 Leider war bei einem Steak der Gargrad falsch, darf eigentlich nicht passieren in so einem Haus.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 858 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "858", "original_id": "1846", "text": "Auch wenn das Ambiente nicht so ansprechend war, hat uns doch das Konzept und die Frische der Speisen überzeugt.", "labels": [["ambiente", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 864 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "864", "original_id": "1857", "text": "Die Vorspeise war per sè schön angerichtet und hat auch geschmeckt.... bekamen was anderes als Burrata wegen laktose, danach ging leider der Tiefflug, angehend von der Karte, in einen Sturzflug über.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 865 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "865", "original_id": "1859", "text": "Mein Fazit: Aufgrund der Essensqualität würde ich dem Brauhaus noch eine Chance geben (darum auch drei Sterne), aber an der Servicequalität muss definitiv schwer gearbeitet werden.", "labels": [["essen", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 960 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "960", "original_id": "2067", "text": "Ich habe dort keine schöne Erfahrung gemacht, dabei ist das Ambiente äußerst angenehm.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 969 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "969", "original_id": "2085", "text": "Atmosphäre des Lokals ist gut, Personal reagierte auf den Wunsch, beim Salat eine Zutat wegzulassen allerdings unflexibel und der Inhaber ist mehr als unfreundlich.", "labels": [["ambiente", "positive"], ["service", "negative"]]}
# [Opposite Polarities] line 977 in ../../11_annotations/experts/acsa_experts_trainset_low.jsonl
# {"id": "977", "original_id": "2106", "text": "Beim Schweinebraten hat die Würze gefehlt, der dazugehörige Salat war fantastisch, die Kruste auch, der Kartoffelknödel war essbar, der Semmelknödel weniger.", "labels": [["essen", "negative"], ["essen", "positive"], ["essen", "neutral"]]}
#
# === Checking ../../11_annotations/ground_truth/acsa_testset_low.jsonl ===
# [Opposite Polarities] line 36 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 35, "text": "Die Gerichte sind immer noch recht groß, aber am Fleisch wird gespart.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 53 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 52, "text": "Bei der Hauptspeise war der Kabeljau verkocht, das Steak und der Lammrücken waren gut, nichts auszusetzen.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 58 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 57, "text": "Schönes Ambiente, aber das reicht leider nicht.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 103 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 104, "text": "Tischreservierung übers Internet zuverlässignegativ: Preis für das Hausbier recht hoch.", "labels": [["preis", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 106 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 107, "text": "Hier gibts Burger und dazu überteuerten Wein, alles ist ziemlich lecker, doch die umliegenden FalaffelPlaces sind alle so viel besser.", "labels": [["preis", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 107 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 108, "text": "Knödel mit Schwammerln Waren lecker, Käsespätzle waren zu matschig.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 189 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 191, "text": "Ist nach wie vor lecker, aber die Portionen sind so klein geworden, dass man nicht mehr satt wird.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 206 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 208, "text": "Vorspeise und Hauptgang waren lecker, Nachspeise enttäuschend.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 217 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 219, "text": "Sehr freundliches Personal, aber das Essen ein absoluter Reinfall.", "labels": [["service", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 268 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 270, "text": "Sehr schade, denn auch die meisten Angestellten sind nett.", "labels": [["service", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 275 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 278, "text": "Der LOC ist gewohnt gut, aber das Essen......", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 279 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 282, "text": "Das reißt dann auch die gute Qualität des Essens nicht mehr raus.", "labels": [["essen", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 305 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 310, "text": "Da hilft auch die gute Location nichts ... Leider", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 308 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 313, "text": "Schade, denn vom Trinken her ist es hier perfekt.", "labels": [["essen", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 315 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 320, "text": "Das Essen : Licht und Schatten: die Antipasti misto mit billigen Mozarella - die Lammkoteletts waren dafür 1a, ebenso die Fusili mit salciche3.", "labels": [["essen", "negative"], ["essen", "positive"]]}
# [Opposite Polarities] line 336 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 341, "text": "die sossedünn/wässrig/geschmack ist anders... schade..das essen meiner partnerin war auch einfach ok...das personal ist das beste am ganzen!", "labels": [["essen", "negative"], ["essen", "neutral"], ["service", "positive"]]}
# [Opposite Polarities] line 355 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 360, "text": "Der Service war sehr aufmerksam und freundlich, ansonsten wirklich alles top... nur mein Kürbisrisotto war der totale Flop.", "labels": [["service", "positive"], ["gesamteindruck", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 379 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 385, "text": "Lediglich die Bedienung war sehr freundlich.", "labels": [["service", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 381 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 387, "text": "Die Bedienung war leider eher unfreundlich und hatte keine Lust entgegen aller anderen Servicekräfte.", "labels": [["service", "negative"], ["service", "positive"]]}
# [Opposite Polarities] line 403 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 409, "text": "Das bestellte Essen war gut, die Beilagen hatten wenig mit typisch portugiesisch zu tun.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 479 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 485, "text": "Das einzig gute war, dass das Essen relativ schnell kam.", "labels": [["service", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 564 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 574, "text": "Die Bedienung ist zwar nett, und die Preise auch recht moderat, aber das Geschmackserlebnis wollte sich einfach nicht so einstellen, wie ich es in Erinnerung hatte.", "labels": [["service", "positive"], ["preis", "neutral"], ["essen", "negative"]]}
# [Opposite Polarities] line 569 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 579, "text": "Sorgfältig zubereitete Speisen, zuvorkommender Service aber vollkommen überteuert bei recht übersichtlichen Portionen.", "labels": [["essen", "positive"], ["service", "positive"], ["essen", "neutral"], ["preis", "negative"]]}
# [Opposite Polarities] line 581 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 591, "text": "Nett, freundlich, bezüglich der Küche aber eindeutig überbewertet.", "labels": [["service", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 681 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 695, "text": "Nur die schöne Einrichtung und die nette Bedienung veranlassten uns, 2 Punkte zu vergeben.", "labels": [["service", "positive"], ["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 714 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 728, "text": "auch wenn die alt gläser kaum gefüllt sind (keine 70%), so ist es immer wieder ein erlebnishier einzukehren.", "labels": [["gesamteindruck", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 747 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 761, "text": "Kindermenü super Preis-Leistung, Getränke ziemlich teuer.", "labels": [["preis", "negative"], ["preis", "positive"]]}
# [Opposite Polarities] line 799 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 814, "text": "Dieser Laden sieht uns nie wieder, auch wenn uns das Ambiente sehr gut gefallen hat.", "labels": [["ambiente", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 803 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 818, "text": "Das Kölsch schmeckt, das Essen leider nicht.", "labels": [["essen", "positive"], ["essen", "negative"]]}
# [Opposite Polarities] line 850 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 866, "text": "Der Laden ist ein wahrer Fuchsbau mit zahlreichen urigen Räumen, die Köbesse sind grimmig-gleichgültig, das Essen gut-bürgerlich.", "labels": [["service", "negative"], ["ambiente", "positive"]]}
# [Opposite Polarities] line 881 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 900, "text": "Bier ist lecker und zu mehr sollte man da nicht einkehren.", "labels": [["essen", "positive"], ["gesamteindruck", "negative"]]}
# [Opposite Polarities] line 887 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 906, "text": "Dann kam das Essen, das war wirklich gut, wenn auch VIEL ZU TEUER!", "labels": [["essen", "positive"], ["preis", "negative"]]}
# [Opposite Polarities] line 903 in ../../11_annotations/ground_truth/acsa_testset_low.jsonl
# {"id": 922, "text": "Klasse Biere, klasse Location aber leider schlechter Service (weder besonders bemüht, noch aufmerksam, keine Ahnung der verwendeten Hopfen Sorten).", "labels": [["essen", "positive"], ["ambiente", "positive"], ["service", "negative"]]}

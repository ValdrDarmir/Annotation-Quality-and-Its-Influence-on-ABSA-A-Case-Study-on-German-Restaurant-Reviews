# %%
import json
from collections import defaultdict

# Define valid categories and polarities (with English mapping)
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities_map = {
    "negativ": "negative",
    "positiv": "positive",
    "neutral": "neutral",
    "konflikt": "conflict",
    "NULL": "NULL"
}

# Load JSON file
with open("../../11_annotations/crowd/acsa/crowd_acsa_raw.json", "r", encoding="utf-8") as f:
    data = json.load(f)

annotator_data = defaultdict(list)

# Process data
for item in data:
    task_data = item.get("data", {})
    task_id = task_data.get("id")
    original_id = task_data.get("original_id", task_id)
    text = task_data.get("text", "")

    for ann in item.get("annotations", []):
        completed_by = ann.get("completed_by")
        labels_list = []

        for result in ann.get("result", []):
            from_name = result.get("from_name")
            val = result.get("value", {})

            if from_name in {"category_polarity", "gender"}:  # allow both names seen in your data
                for lbl in val.get("choices", []):
                    parts = lbl.split("-")
                    category = parts[0].lower()
                    polarity = parts[1].lower() if len(parts) > 1 else "NULL"
                    # Translate polarity to English
                    polarity = valid_polarities_map.get(polarity, polarity)
                    labels_list.append([category, polarity])

        if labels_list:
            annotator_data[completed_by].append({
                "id": str(task_id),
                "original_id": str(original_id),
                "text": text,
                "labels": labels_list
            })

# Validation and saving
for annotator, entries in annotator_data.items():
    filename = f"results_single_acsa_crowd/{annotator}.jsonl"
    with open(filename, "w", encoding="utf-8") as f:
        for entry in entries:
            json.dump(entry, f, ensure_ascii=False)
            f.write("\n")

    # Checks
    if len(entries) != 200:
        # print(f"Length Error: Annotator {annotator} has {len(entries)} entries, expected 200.")
        None

    for entry in entries:
        for lbl in entry["labels"]:
            category, polarity = lbl
            # Check category
            if category not in valid_categories:
                print(f"Category Error in annotator {annotator}, id {entry['id']}: invalid category '{category}'")
            # Check polarity
            if polarity not in {"negative", "positive", "neutral", "conflict", "NULL"}:
                print(f"Polarity Error in annotator {annotator}, id {entry['id']}: invalid polarity '{polarity}'")

print("Processing and validation complete.")
# Out:
# Processing and validation complete.

# %%
#!/usr/bin/env python3
import json
import os
import glob
from collections import Counter, defaultdict

# Config
RESULTS_DIR = "results_single_acsa_crowd/original"       # where annotator jsonl files live
INPUT_DIR = "results_single_acsa_crowd"
TRAINSET_FILE = "data/trainset_1000.jsonl"
SPLIT_SIZE = 200                      # split size (0-199,200-399,...)
NUM_SPLITS = 5                        # 1000 / 200

def load_trainset(path):
    train = []
    id_to_index = {}
    with open(path, "r", encoding="utf-8") as f:
        for idx, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
            except json.JSONDecodeError as e:
                raise RuntimeError(f"Error parsing trainset line {idx}: {e}")
            train.append(obj)
            id_to_index[str(obj.get("id"))] = idx
    return train, id_to_index

def load_jsonl(path):
    items = []
    with open(path, "r", encoding="utf-8") as f:
        for line_no, line in enumerate(f, 1):
            s = line.strip()
            if not s:
                continue
            try:
                obj = json.loads(s)
            except json.JSONDecodeError as e:
                raise RuntimeError(f"Error parsing {path} line {line_no}: {e}")
            items.append(obj)
    return items

def write_jsonl(path, items):
    with open(path, "w", encoding="utf-8") as f:
        for obj in items:
            json.dump(obj, f, ensure_ascii=False)
            f.write("\n")

def detect_split(present_ids, id_to_index):
    # Count which split each id falls into (based on trainset index)
    split_counts = Counter()
    missing_ids = []
    for pid in present_ids:
        idx = id_to_index.get(pid)
        if idx is None:
            missing_ids.append(pid)
        else:
            split = idx // SPLIT_SIZE
            split_counts[split] += 1
    if not split_counts:
        # No match at all -> default to split 0 and report
        return 0, missing_ids
    best_split = max(split_counts.items(), key=lambda x: (x[1], -x[0]))[0]
    return best_split, missing_ids

def complete_file(file_path, trainset, id_to_index):
    # Load annotator file
    items = load_jsonl(file_path)
    present_map = {str(item.get("id")): item for item in items}
    present_ids = list(present_map.keys())

    best_split, not_found_in_train = detect_split(present_ids, id_to_index)

    start = best_split * SPLIT_SIZE
    end = start + SPLIT_SIZE
    split_train = trainset[start:end]

    train_ids_in_split = [str(x.get("id")) for x in split_train]

    # Build final list in trainset order: either existing annotator entry or filled entry
    final_entries = []
    added_ids = []
    kept_ids = []
    for ts in split_train:
        ts_id_str = str(ts.get("id"))
        if ts_id_str in present_map:
            # Keep annotator's entry, but ensure it contains original_id and text (fill from trainset if missing)
            entry = present_map[ts_id_str]
            if "original_id" not in entry and "original_id" in ts:
                entry["original_id"] = ts.get("original_id")
            if "text" not in entry and "text" in ts:
                entry["text"] = ts.get("text")
            # If this annotator entry is missing labels key, preserve it (do not auto-insert)
            if "labels" not in entry:
                entry["labels"] = []
            final_entries.append(entry)
            kept_ids.append(ts_id_str)
        else:
            # Create missing entry using trainset entry + empty labels
            new_entry = {
                "id": str(ts.get("id")),
                "original_id": str(ts.get("original_id")),
                "text": ts.get("text"),
                "labels": []
            }
            final_entries.append(new_entry)
            added_ids.append(ts_id_str)

    # Any present entries outside the chosen split will be reported and dropped
    outsiders = [pid for pid in present_ids if pid not in set(train_ids_in_split)]

    # Final safety checks
    if len(final_entries) != SPLIT_SIZE:
        raise RuntimeError(f"Internal error: final_entries length is {len(final_entries)} (expected {SPLIT_SIZE}) for file {file_path}")

    # Overwrite file
    write_jsonl(file_path, final_entries)

    summary = {
        "file": file_path,
        "chosen_split": (start, end-1),
        "kept_count": len(kept_ids),
        "added_count": len(added_ids),
        "added_ids": added_ids,
        "outsiders_dropped": outsiders,
        "ids_not_found_in_trainset": not_found_in_train
    }
    return summary

def main():
    if not os.path.exists(TRAINSET_FILE):
        print(f"Trainset file not found: {TRAINSET_FILE}")
        return

    trainset, id_to_index = load_trainset(TRAINSET_FILE)

    files = sorted(glob.glob(os.path.join(INPUT_DIR, "*.jsonl")))
    if not files:
        print(f"No .jsonl files found in {INPUT_DIR}")
        return

    all_summaries = []
    for fpath in files:
        try:
            summary = complete_file(fpath, trainset, id_to_index)
            all_summaries.append(summary)
            print(f"Processed {os.path.basename(fpath)}: split {summary['chosen_split'][0]}-{summary['chosen_split'][1]}, "
                  f"kept {summary['kept_count']}, added {summary['added_count']}, dropped outsiders {len(summary['outsiders_dropped'])}")
            if summary["outsiders_dropped"]:
                print("  -> Dropped outsider ids (not in chosen split):", summary["outsiders_dropped"])
            if summary["ids_not_found_in_trainset"]:
                print("  -> IDs present in file but not found in trainset:", summary["ids_not_found_in_trainset"])
        except Exception as e:
            print(f"Error processing {fpath}: {e}")

    # Optionally write a summary JSON
    summary_path = os.path.join(RESULTS_DIR, "fill_summary.json")
    with open(summary_path, "w", encoding="utf-8") as sf:
        json.dump(all_summaries, sf, ensure_ascii=False, indent=2)

    print(f"\nDone. Summary saved to {summary_path}")

if __name__ == "__main__":
    main()
# Out:
# Processed 91945.jsonl: split 400-599, kept 200, added 0, dropped outsiders 0
# Processed 91947.jsonl: split 800-999, kept 199, added 1, dropped outsiders 0
# Processed 91948.jsonl: split 0-199, kept 198, added 2, dropped outsiders 0
# Processed 91949.jsonl: split 200-399, kept 199, added 1, dropped outsiders 0
# Processed 91950.jsonl: split 400-599, kept 200, added 0, dropped outsiders 0
# Processed 91951.jsonl: split 600-799, kept 200, added 0, dropped outsiders 0
# Processed 91952.jsonl: split 800-999, kept 200, added 0, dropped outsiders 0
# Processed 91954.jsonl: split 200-399, kept 200, added 0, dropped outsiders 0
# Processed 91955.jsonl: split 400-599, kept 198, added 2, dropped outsiders 0
# Processed 91956.jsonl: split 600-799, kept 200, added 0, dropped outsiders 0
# Processed 97366.jsonl: split 0-199, kept 189, added 11, dropped outsiders 0
# Processed 97367.jsonl: split 0-199, kept 200, added 0, dropped outsiders 0
# Processed 97368.jsonl: split 200-399, kept 196, added 4, dropped outsiders 0
# Processed 97534.jsonl: split 600-799, kept 194, added 6, dropped outsiders 0
# Processed 97536.jsonl: split 800-999, kept 196, added 4, dropped outsiders 0
#
# Done. Summary saved to results_single_acsa_crowd/original\fill_summary.json

# %%
import os
import json
import glob

# Folders
RESULTS_DIR = "results_single_acsa_crowd"  # where annotator jsonl files live

# Validation sets
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities = {"negative", "positive", "neutral", "conflict", "NULL"}

def load_jsonl(path):
    entries = []
    with open(path, "r", encoding="utf-8") as f:
        for line_no, line in enumerate(f, 1):
            s = line.strip()
            if not s:
                continue
            try:
                obj = json.loads(s)
            except json.JSONDecodeError as e:
                print(f"JSON error in {path}, line {line_no}: {e}")
                continue
            entries.append(obj)
    return entries

def validate_file(path):
    annotator = os.path.basename(path).replace(".jsonl", "")
    entries = load_jsonl(path)

    # Check file length
    if len(entries) != 200:
        print("Length!")
        None

    # Check each entry
    for entry in entries:
        for lbl in entry.get("labels", []):
            if not lbl:
                continue
            if len(lbl) != 2:
                print(f"Format Error in {annotator}, id {entry['id']}: label {lbl} is not tuple")
                continue
            category, polarity = lbl

            # Category check
            if category not in valid_categories:
                print(f"Category Error in {annotator}, id {entry['id']}: invalid category '{category}'")

            # Polarity check
            if polarity not in valid_polarities:
                print(f"Polarity Error in {annotator}, id {entry['id']}: invalid polarity '{polarity}'")


def main():
    files = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.jsonl")))
    if not files:
        print(f"No .jsonl files found in {RESULTS_DIR}")
        return

    for path in files:
        validate_file(path)

    print("Processing and validation complete.")

if __name__ == "__main__":
    main()
# Out:
# Processing and validation complete.

# %%
import os
import json
import glob
from collections import Counter, defaultdict

# --- Helper functions ---
def get_frequency_for_counts(counts, minimum):
    """Return the frequency count based on minimum appearance across splits."""
    return sorted(counts, reverse=True)[0:minimum][minimum-1]

def get_unique_keys(dict_list):
    """Return all unique keys across a list of dictionaries."""
    unique_keys = set()
    for d in dict_list:
        unique_keys.update(d.keys())
    return list(unique_keys)

def merge_aspect_lists(aspect_lists, minimum_appearance=2, oid=None):
    """
    Merge multiple aspect lists based on a minimum appearance, 
    with warning for low-frequency aspects.
    """
    counter_exclude = 0
    aspect_lists_counter = []
    for aspect_list in aspect_lists:
        aspect_counter = dict(Counter(["#####".join(aspect) for aspect in aspect_list]))
        aspect_lists_counter.append(aspect_counter)
        
    unique_tuples = get_unique_keys(aspect_lists_counter)

    label = []
    for tuple_str in unique_tuples:
        counts = [asp.get(tuple_str, 0) for asp in aspect_lists_counter]
        total_count = sum(counts)
        
        if total_count < minimum_appearance:
            counter_exclude += 1
            continue  # skip weak aspects
        
        count_tuple = get_frequency_for_counts(counts, minimum_appearance)
        tuple_reverse = tuple(tuple_str.split("#####"))
        label += count_tuple * [tuple_reverse]
        
    return label, counter_exclude


# --- Main script ---
RESULTS_DIR = "results_single_acsa_crowd/"
OUTPUT_FILE = "final/trainset_crowd_acsa.jsonl"
os.makedirs("final", exist_ok=True)

# Load all annotator files
files = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.jsonl")))
print(f"Found {len(files)} annotator files.")

# Group entries by ID
entries_by_id = defaultdict(list)

def load_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        return [json.loads(line) for line in f if line.strip()]

for path in files:
    for entry in load_jsonl(path):
        entries_by_id[entry["id"]].append(entry)

# Merge by majority vote
merged_entries = []
for oid, entry_list in sorted(entries_by_id.items(), key=lambda x: int(x[0])):
    if not entry_list:
        continue

    text = entry_list[0]["text"]
    original_id = entry_list[0]["original_id"]

    # Collect all label sets
    label_sets = [e.get("labels", []) for e in entry_list]

    # Merge with majority voting
    merged_labels, excluded = merge_aspect_lists(label_sets, minimum_appearance=2, oid=oid)

    merged_entries.append({
        "id": str(oid),
        "original_id": original_id,
        "text": text,
        "labels": merged_labels
    })

# Save merged dataset
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    for entry in merged_entries:
        json.dump(entry, f, ensure_ascii=False)
        f.write("\n")

print(f"✅ Merged dataset written to {OUTPUT_FILE} with {len(merged_entries)} entries.")
# Out:
# Found 15 annotator files.
# ✅ Merged dataset written to final/trainset_crowd_acsa.jsonl with 1000 entries.

# %%
import json

INPUT_FILE = "final/trainset_crowd_acsa.jsonl"
OUTPUT_FILE = "final/trainset_crowd_acsa_noconflict.jsonl"

with open(INPUT_FILE, "r", encoding="utf-8") as f_in, open(OUTPUT_FILE, "w", encoding="utf-8") as f_out:
    for line in f_in:
        if not line.strip():
            continue
        entry = json.loads(line)

        # filter out labels with conflict polarity
        filtered_labels = [lbl for lbl in entry.get("labels", []) if lbl[1] != "conflict"]

        entry["labels"] = filtered_labels
        json.dump(entry, f_out, ensure_ascii=False)
        f_out.write("\n")

print(f"✅ File cleaned and saved to {OUTPUT_FILE}")
# Out:
# ✅ File cleaned and saved to final/trainset_crowd_acsa_noconflict.jsonl

# %%
import json
from collections import defaultdict

# Define valid categories and polarities (with English mapping)
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities_map = {
    "negativ": "negative",
    "positiv": "positive",
    "neutral": "neutral",
    "konflikt": "conflict",
    "NULL": "NULL"
}

# Load JSON file
with open("../../11_annotations/students/acsa/students_raw.json", "r", encoding="utf-8") as f:
    data = json.load(f)

annotator_data = defaultdict(list)

# Process data
for item in data:
    task_data = item.get("data", {})
    task_id = task_data.get("id")
    original_id = task_data.get("original_id", task_id)
    text = task_data.get("text", "")

    for ann in item.get("annotations", []):
        completed_by = ann.get("completed_by")
        labels_list = []
        meta_dict = {}
        comments_list = []

        for result in ann.get("result", []):
            from_name = result.get("from_name")
            val = result.get("value", {})

            if from_name in {"category_polarity", "gender"}:  # allow both naming variants
                for lbl in val.get("choices", []) + val.get("labels", []):
                    parts = lbl.split("-")
                    category = parts[0].lower()
                    polarity = parts[1].lower() if len(parts) > 1 else "NULL"
                    # Translate polarity
                    polarity = valid_polarities_map.get(polarity, polarity)
                    labels_list.append({"category": category, "polarity": polarity})

            elif from_name == "meta":
                # Collect meta choices
                choices = val.get("choices", [])
                if choices:
                    meta_dict["choices"] = choices

            elif from_name == "comment":
                # Collect free text comments
                comment_texts = val.get("text", [])
                comments_list.extend(comment_texts)

        if labels_list:
            annotator_data[completed_by].append({
                "id": str(task_id),
                "original_id": str(original_id),
                "text": text,
                "labels": labels_list,
                "meta": meta_dict,
                "comment_authors": comments_list
            })

# Validation and saving
for annotator, entries in annotator_data.items():
    filename = f"results_single_acsa_meta/{annotator}.jsonl"
    with open(filename, "w", encoding="utf-8") as f:
        for entry in entries:
            json.dump(entry, f, ensure_ascii=False)
            f.write("\n")

    # Checks
    if len(entries) != 200:
        # print(f"Length Error: Annotator {annotator} has {len(entries)} entries, expected 200.")
        None

    for entry in entries:
        for lbl in entry["labels"]:
            category = lbl["category"]
            polarity = lbl["polarity"]
            # Check category
            if category not in valid_categories:
                print(f"Category Error in annotator {annotator}, id {entry['id']}: invalid category '{category}'")
            # Check polarity
            if polarity not in {"negative", "positive", "neutral", "conflict", "NULL"}:
                print(f"Polarity Error in annotator {annotator}, id {entry['id']}: invalid polarity '{polarity}'")

print("Processing and validation complete.")
# Out:
# Processing and validation complete.

# %%
import os
import json
import pandas as pd
from collections import Counter

folder = "results_single_acsa_meta"
rows = []

# Loop through all jsonl files
for filename in os.listdir(folder):
    if filename.endswith(".jsonl"):
        annotator_id = filename.replace(".jsonl", "")
        counter = Counter()
        comment_count = 0

        with open(os.path.join(folder, filename), "r", encoding="utf-8") as f:
            for line in f:
                entry = json.loads(line)

                # Count meta choices
                meta = entry.get("meta", {})
                choices = meta.get("choices", [])
                counter.update(choices)
                text = entry.get("text", [])
                labels = entry.get("labels", [])
                # Count comments
                comments = entry.get("comment_authors", [])
                if comments == []:
                    continue
                else:
                    print(text, "\n", labels, "\n", comments, "\n\n")
                comment_count += len(comments)

        rows.append({
            "annotator": annotator_id,
            # K = Fehlender Kontext aus der Bewertung könnte die Annotation beeinflussen.
            "K": counter.get("K", 0),
            # S = Die Annotation war schwierig.
            "S": counter.get("S", 0),
            "total_choices": sum(counter.values()),
            "comments": comment_count
        })

# Create dataframe
df = pd.DataFrame(rows)
print(df)

# Save to CSV (optional)
df.to_csv("meta_counts_with_comments.csv", index=False)
# Out:
# Der Teller ist gut gefüllt, fritierte Sardinen, gegrillte Paprika, Datteln in Speck und Ziegenkäse im Speck, nichts Überraschendes, nichts Außergewöhnliches.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Viel, vermutlich aber nicht lecker']
#
#
# !Auch wenn die Bedienung sich dafür entschuldigt hat, war es kein schönes Erlebnis.
#  [{'category': 'service', 'polarity': 'conflict'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['War die Bedienung freundlich?']
#
#
# Der Auslieferungsfahrer war sehr nett und hat sich entschuldigt.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'negative'}, {'category': 'service', 'polarity': 'conflict'}]
#  ['Vermutlich lange Wartezeit ']
#
#
# Von dünn und knusprig, goldbraun gebraten keine Spur.
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Gericht sollte ergänzt werden']
#
#
# Die Qualität des Essens fand ich aber sehr durchschnittlich.
#  [{'category': 'essen', 'polarity': 'neutral'}, {'category': 'essen', 'polarity': 'conflict'}]
#  ['Weder gut noch schlecht']
#
#
# Insgesamt reichten die drei Gänge nicht zum satt werden.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Es wird nicht erwähnt ob das Essen trotzdem gut war']
#
#
# Essen war mittelmäßig, Preise Düsseldorfer Niveau
#  [{'category': 'essen', 'polarity': 'neutral'}, {'category': 'preis', 'polarity': 'neutral'}]
#  ['Düsseldorfer Preise, gut oder schlecht?']
#
#
# Schade für die ehemalige Perle im LOC.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Man versteht nicht was gemeint ist']
#
#
# Das Stück Torte war handwerklich fehlerfrei.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Handwerklich fehlerfrei heißt nicht unbedingt gut. Kann auch schön ausschauen und scheiße schmecken']
#
#
# Bei mir war es nicht viel besser.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'gesamteindruck', 'polarity': 'neutral'}]
#  ["Was war nicht viel besser? Essen, Service, Ambiente? Hab's jetzt mal auf Gesamteindruck, aber da auch... Nicht viel besser als Totalreinfall oder nicht viel besser als Durchschnitt?"]
#
#
# Wagner muss man mögen............die Kellner sind schon seit mehr als 20 Jahren die gleichen und man muss Sie mögen.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'neutral'}, {'category': 'ambiente', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'neutral'}]
#  ['Kann positiv oder negativ ausgelegt werden. Man *muss* sie mögen = positiv, man muss sie *mögen* = neutral bis negativ']
#
#
# Fränkische Bratwürste, die waren gut, aber das Sauerkraut dazu hat nach gar nichts geschmeckt.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Positiv + negativ = Konflikt?']
#
#
# Die Location spannend, das Personal grundsätzlich freundlich, das Frühstück allerdings qualitativ durchschnittlich.
#  [{'category': 'essen', 'polarity': 'neutral'}, {'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'neutral'}]
#  ['Wie "spannend"? Kann auch wieder je nach Betonung ausgelegt werden, deswegen mal neutral']
#
#
# Beides sehr gut.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Was "beides"? Essen und Service? Preis und Ambiente? Keine Ahnung, deswegen Gesamteindruck']
#
#
# Für diesen Preis trotzdem eine Zumutung.
#  [{'category': 'preis', 'polarity': 'negative'}]
#  ['Keine Ahnung auf was sich das bezieht... Essen/Getränke oder Service ...?']
#
#
# Aber er war nicht ganz schlecht.
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'service', 'polarity': 'negative'}, {'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Was war nicht ganz schlecht? Keine Ahnung, deswegen mal alles, was möglicherweise schlecht sein hätte können angekreuzt']
#
#
# das spätere essen (Pizza) war wirklich gut, aber so viel Zeit während der Woche haben wir nicht und werden deshalb auch nicht wieder kommen.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'negative'}]
#  ['Hab jetzt mal Service negativ, weil ich keine Ahnung hab, ob es an der Küche oder dem Service gelegen hat, dass die solange warten mussten']
#
#
# Schade, ansonsten eine sehr schöne Gastronomie mit super netten Service.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Liegts am schlechten Essen? Teuren Preisen? Keine Ahnung, jetzt muss mal wieder der Gesamteindruck herhalten']
#
#
# Die Portionen waren sehr gross und eigentlich zu viel für uns älteren Leute.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'essen', 'polarity': 'negative'}]
#  ['Zu viel Essen als etwas Negatives dargestellt ']
#
#
# Man muss dem gesamten Team mit ihren Chefs großen Respekt zollen, wie sie es in der Gastronomiebranche geschafft haben - in diesen verrückten schwierigen vergangenen 2 Jahren- eine tolle Küche und ausgesprochen nettes Personal zu halten und zu motivieren, bei einer nicht mehr reichlich vorhandenen Auswahl des gleichen.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'essen', 'polarity': 'conflict'}, {'category': 'service', 'polarity': 'positive'}]
#  ['nicht mehr reichlich vorhandene Auswahl klingt negativ obwohl der gesamt Kommentar eigentlich loben will, deswegen Konflikt ']
#
#
# Zwei Punkte, weil: Bedienung sehr aufmerksam und freundlich.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'neutral'}]
#  ['2 punkte eher wenig deswegen Gesamteindruck neutral , da Kompliment an Bedienung ']
#
#
# Schade, ansonsten eine sehr schöne Gastronomie mit super netten Service.
#  [{'category': 'service', 'polarity': 'positive'}]
#  ['zu wenig info warum es schade war']
#
#
# Sowohl Vorspeisen als auch Hauptgang hat überrascht.
#  [{'category': 'essen', 'polarity': 'neutral'}]
#  ['Überrascht aber weder angegebn ob positiv noch negativ. Man kann keine Aussage darüber treffen inwiefern die Aussage gedeutet werden kann.']
#
#
# Sehr Schade!
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Kein Kontext warum es Schade war deswegen kann keine genaue Begründung gefunden werden nur, dass vermutlich etwas negativ war.']
#
#
# Schade!
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Kein Angabe inwiefern etwas schade war.']
#
#
# Selbst unter Corona hatte das Restaurant sein Level gehalten.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Level gehalten geht von einem positiven Grund-Gesamteindruck aus ']
#
#
# Das Restaurant ist LOC und die Atmosphäre gleicht eher fast food als vera cucina italiana!
#  [{'category': 'ambiente', 'polarity': 'negative'}]
#  ['Was ist LOC? Je nach dem worauf Ambiente abziehlt unterschiedlich interpretierbar jedoch ohne weiteren Kontext als negativ einstufbar']
#
#
# Sehr gute Kohlparty, Essen ausgezeichnet, DJ spitze.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Kohlparty?']
#
#
# Brandy rundeten diesen einmaligen Abend ab.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Brandy ist Trinken ->Zählt nicht zu essen aber zeugt von gutem Gesamteindruck']
#
#
# Ich fand es sehr solide in puncto Service, Ambiente und Auswahl an Speisen und Getränken.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}]
#  ['Sehr solide = leicht positiv']
#
#
# Ich habe schon deutlich besser gegessen und nur die Hälfte bezahlt.
#  [{'category': 'essen', 'polarity': 'conflict'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Keine Explizite aussage über essen nur vergleich in Zusammenhang mit Preis']
#
#
# Das Esser wurde sehr schnell zubereitet und war schnell da.
#  [{'category': 'service', 'polarity': 'positive'}]
#  ['Schnelligkeit Essen kann als Service oder Gesamteindruck gezählt werden ']
#
#
# Sie waren trocken und fad.
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Wahrscheinlich bezogen auf essen, jedoch fehlender Kontext, theoretisch auch möglich das auf Bedienung bezogen jedoch unwahrscheinlich']
#
#
# Innovative Chefs mit intensivem Internet-Marketing; anfangs dachte ich, fast „zuviel des Guten“, was wird da auf mich zukommen.
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Endmeinung nicht enthalten']
#
#
# Und kein deutsches, denkt man schon das man hier auch sehr gut essen kann.
#  [{'category': 'essen', 'polarity': 'positive'}]
#  ['Und kein deutsches?']
#
#
# Leider war das Lamm wieder durch obwohl Rare bestellt da Kalbsschnitzel war das Fleisch von schlechter Qualität?
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Schlechte Grammatik des Verfassers']
#
#
# Allerdings mussten wir noch weitere 30 Minuten bis zur Lieferung warten.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Lange wartezeit = schlechter Service']
#
#
# Der Auslieferungsfahrer war sehr nett und hat sich entschuldigt.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Was das problem?']
#
#
# Das findet man sonst nicht, und macht die Faszination LOC aus.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Kontext fehlt aber wahrscheinlich positiv zu bewerten']
#
#
# Die Lage des Lokals am LOC ist perfekt, die Keller-Räumlichkeiten sind gemütlich - da kommen die Kunden sowieso, da braucht man sich wohl keine Mühe zu geben.
#  [{'category': 'ambiente', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Keine mühe geben heißt?']
#
#
# Damals fanden wir das Restaurant Weltklasse.
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['damals gut jetzt?']
#
#
# Früher hat man das antiquierte Ambiente nicht beachtet, weil die Steaks sehr gut waren.
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'ambiente', 'polarity': 'negative'}]
#  ['Altmodisches wort']
#
#
# Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .
#  [{'category': 'ambiente', 'polarity': 'positive'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Gratulieren schmerzhaft?']
#
#
# Jeder Restauranttester schlägt wahrscheinlich die Hände über dem Kopf zusammen, sollte er jemals so ein Essen serviert bekomnen
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Hände über den Kopf zusammenschlagen als negativ interpretiert']
#
#
# Das HRC in LOC zählt leider zu den schlechtesten Cafés die wir je erlebt haben.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Was heißen die Abkürzungen?']
#
#
# Leckere Suppen und Fischgerichte wie Dorade.
#  [{'category': 'essen', 'polarity': 'positive'}]
#  ['Dorade?']
#
#
# Fast alles in Ordnung.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Fast alles? Interpretiert alles gut außer eine Kleinigkeit?']
#
#
# Bier wird zwischenzeitlich warm.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Grund? langsames trinken? Ist der grund das bier oder der service?']
#
#
# Da ist viel Luft nach oben.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'gesamteindruck', 'polarity': 'neutral'}]
#  ['Muss nicht unbedingt schlecht heißen aber wahrscheinlich']
#
#
# Ein absolutes Durstessen.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Was ist damit gemeint? Interpretiert als kein trinken zum essen']
#
#
# Alles in allem: schneller Service, gutes Essen, Getränke zu teuer und am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'positive'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Was heißt "am regelmäßigen Austausch des Wassers vom LOC arbeiten wir noch"?']
#
#
# Die Krönung waren dann die 6,50 Euro für den 0,1 l Rosenkir.
#  [{'category': 'preis', 'polarity': 'positive'}]
#  ['Preiswahrnehmung kannn unterschiedlich sein, ich find billig']
#
#
# Die Preise waren die gleichen wie früher: schade!
#  [{'category': 'preis', 'polarity': 'negative'}]
#  ['Macht keinen Sinn oder?']
#
#
# Die Bedingung reagierte darauf mit einem Schulterstücken und sie essen den auch, also soll er uns schmecken.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['2.Satzteil unverständlich']
#
#
# 2mal Fisch, 1mal herzhafte südamerikanische (!)
#  [{'category': 'essen', 'polarity': 'neutral'}]
#  ['Keine Meinung enthalten']
#
#
# Selbst unter Corona hatte das Restaurant sein Level gehalten.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'neutral'}, {'category': 'gesamteindruck', 'polarity': 'positive'}, {'category': 'preis', 'polarity': 'neutral'}]
#  ['Keine Einzelkategorien angesprochen']
#
#
# Das Restaurant ist LOC und die Atmosphäre gleicht eher fast food als vera cucina italiana!
#  [{'category': 'ambiente', 'polarity': 'negative'}]
#  ['Was heißt LOC?']
#
#
# Es war das Geld nicht wert.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Wäre die Bewertung positiver, wenn die Gerichte billiger wären oder würde dann an etwas anderem etwas ausgesetzt werden?']
#
#
# Wenn man sich für Tapas beim LOC entscheidet, möchte man auch entsprechende Tapas bekommen.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Waren die Tapas dennoch lecker? Wird hierbei eher die Küche kritisiert und nicht das Essen an sich, da es vielleicht zwar gut, aber nicht das war, was man erwartet hatte?']
#
#
# Außerdem auch eine sehr gute Weinkarte !
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Gesamteindruck positiv bewertet wegen "Außerdem", das Wort suggeriert, dass der Gesamteindruck vorher bereits gelobt wurde. ']
#
#
# Es war so weich gekocht, dass ich es durch die geschlossenen Zahnreihen ziehen konnte.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Je nachdem was bestellt wurde, kann dies entweder eine sehr positive oder sehr negative Rezension sein, Kontext fehlt. ']
#
#
# Eine Reservierung für 2 Personen war im Vorfeld (Tage vorher) nicht möglich.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Gilt eine Reservierung als Serviceleistung? ']
#
#
# Kaeufer ging einige Tage spaeter mit Quittung um dies zu klaeren und wurde als Luegner dargestellt.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Wird hierbei der Service bemängelt oder fällt das schon als negativer Gesamteindruck? Fehlender Kontext. ']
#
#
# Eine Pizzabude ohne Ambitionen.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Nichtssagend. ']
#
#
# Da ist der kleine Landgasthof im LOC Umland wesentlich flexibler, wenn man im Krankheitsfall eine Kohlfahrt (z.B.) absagen muss!
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Komische Bewertung.']
#
#
# Ich habe das Restaurant dann hungrig verlassen.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Woran lag es? War das Essen schlecht oder der Service zu langsam, gab es keine freien Tische mehr? Kontext.']
#
#
# Von Mal zu Mal wurde es immer schlechter…doch dieses Wochenende wurde einfach wieder übertroffen.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Wurde das Essen von Mal zu Mal schlechter oder der gesamte Aufenthalt in dem Restaurant?']
#
#
# Am Rand kalt, in der Mitte heiß.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Ist das denn wirklich negativ oder kann dies in manchen Gerichten sogar besser sein?']
#
#
# Der „Gruß aus der Küche“ für 5 Personen sehr mager.
#  [{'category': 'service', 'polarity': 'conflict'}]
#  ['Zählt das als Problem mit dem Essen oder dem Service? Schließlich wird nicht der Geschmack bewertet, sondern die Menge. ']
#
#
# Als Dessert ein sehr gut geschenkter Sambuca (7,50 €) und ein Linie-Aquavit (4,90 €).
#  [{'category': 'essen', 'polarity': 'positive'}]
#  ['Zuerst dachte ich der Sambuca wurde dem Kunden vom Restaurant kostenlos zur Verfügung gestellt, bei genauerem Lesen verstand ich doch, dass es sich hierbei um Alkohol handelt. ']
#
#
# Zumal ich hungrig nach Hause ging.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Selber Konflikt wie bei einer anderen Rezension: Woran hat es gelegen? War das Essen schlecht oder der Service und man erhielt das Essen erst gar nicht? Kontext fehlt.']
#
#
# Sehr schade!
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Unklar, nichtssagend.']
#
#
# Ist ganz nett.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Zählt das bereits als positiv oder kann man hier noch von neutral sprechen?']
#
#
# Schade eigentlich.
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Ich denke dieselbe Aussage gab es bereits. Unklar, was genau schade ist. ']
#
#
# Es hat aber wenigstens einigermaßen ( aber eben auch nicht sehr gut) geschmeckt.
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Kann das auch als neutral gelten? Da in Klammern von nicht "sehr" gut gesprochen wird, also doch gut nur nicht eben sehr?']
#
#
# Preis / Leistung stimmt.
#  [{'category': 'preis', 'polarity': 'neutral'}]
#  ['Ist das schon als positiv zu bewerten? Aber eigentlich ja eine sehr neutrale Aussage meiner Meinung nach.']
#
#
# Vergangene Weihnachten dort gewesen,unvergesslicher Heiligabend,-und jetzt?
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Was soll man unter dem "und jetzt" verstehen? Jetzt ist das Restaurant nicht mehr so gut? Oder findet die Person keine vergleichbare Lokalität für das diesjährige Fest? Kontext.']
#
#
# Heute haben wir leider eine sehr schlechte Erfahrung gemacht, weshalb das auch unser letzter Besuch bei RESTAURANT_NAME war.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Schlechte Erfahrung im Bezug auf was? Fehlender Kontext. ']
#
#
# LOC mit abwechslungsreichen Speiseangebot, der Service ist eingedeutscht.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'conflict'}]
#  ['Bedeutet ein "eingedeutschter Service", dass dieser schlecht ist oder handelt es sich hierbei um ein Kompliment? Je nach Restauranttyp anders zu verstehen. ']
#
#
# Pancakes, Brot, Brötchen, Kuchen, Müsli, Joghurt, Säfte, Tee, Kaffee, Wurst, Käse, Mett, Eier, Bacon, Würstchen usw. Einfach klasse und wenn man einen Platz an der LOC bekommt, umso schöner.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}]
#  ['"Wenn man einen Platz an der LOC bekommt, umso schöner." Wird hier vom Ambiente gesprochen? Etwas verwirrend.']
#
#
# Lächerlich!
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Fehelender Kontext erschwert die Annotation.']
#
#
# Die Crew (alle im gleichen Outfit - alle sprechen italienisch mit den Gästen) soll den Kunden das Gefühl vermitteln wirklich in LOC zu sein…ähnlich kennen wir das aus LOC…hierfür würde ich für die schauspielerische Leistung glatt 3 Punkte vergeben.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Man weiß nicht ob es sich hierbei um eine Skala von 1-10 handelt, wobei 3 eine relativ schlechte Leistung wäre oder z.B. um eine Skala von 1-5, wobei 3 mittelmäßig wäre. ']
#
#
# Unsere Essen waren beide mehr oder weniger kalt!
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Kaltes Essen bedeutet ja nicht gleich schlecht schmeckend, also würde ich eher den Service schlecht bewerten.']
#
#
# Da gibt es überhaupt nichts zu meckern.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Das ist erneut ein Satz, der wohl je nachdem woher man kommt, als sehr positiv oder einfach nur neutral bewertet werden kann. ']
#
#
# Nun ja, darauf hin Rechnung bestellt - was auch ein wenig schwierig war - und zur Konkurrenz auf der anderen Seite gewechselt.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Warum war es schwierig die Rechnung zu "bestellen"? Was genau hat nicht gefallen? Fehlender Kontext. Wegen dem "auch" schätze ich jedoch, dass mehrere Sachen nicht gefallen haben und der Gesamteindruck somit negativ war.']
#
#
# Die Speisen sind türkische Standard Küche etwas über dem Durchschnitt.
#  [{'category': 'essen', 'polarity': 'neutral'}]
#  ['Ist "etwas über dem Durchschnitt" bereits als positiv zu verstehen?']
#
#
#  Sooft nach LOC und noch nie hier Essen, was für eine Zeitverschwendung!
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['War der Besuch eine Zeitverschwendung? Empfindet der Besucher es als Zeitverschwendung, dass er so oft in LOC war, aber nie hier gegessen hat? Unverständlich geschrieben.']
#
#
# Nette Kellnerinnen und Kellner in nettem Outfit, mit Gatsby-Mütze und Hosenträger – also: Ich habe mich wohlgefühlt.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}]
#  ['Den Kommentar würde ich sowohl dem Service als auch dem Ambiente positiv zuordnen. ']
#
#
# Man muss alles daran mögen, aber für ein bis vier Alt sollte man hier schon einkehren, wenn man in LOC ist.
#  [{'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Sehr verwirrender Satz.']
#
#
# Das war leider das letzte Mal!
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Woran hat es gelegen? Das "leider" suggeriert, dass dies als schade empfunden wird, war man also vorher bereits schon einmal dort und alles hat gepasst?']
#
#
# Aber was hier aktuell kredenzt wird und vor allem das unprofessionelle Ambiente schreckt ab.
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'ambiente', 'polarity': 'negative'}]
#  ['Unter "kredenzt" versteht man ja was hier serviert wird, also denke ich bezieht sich die Aussage auf das Essen/Trinken und nicht den Service an sich?']
#
#
# Ein angenehmer Mittagstisch.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Ist das noch Ambiente oder schon Gesamteindruck? ']
#
#
# Wagner muss man mögen............die Kellner sind schon seit mehr als 20 Jahren die gleichen und man muss Sie mögen.
#  [{'category': 'service', 'polarity': 'conflict'}, {'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Unklar wer/was "Wagner" ist.']
#
#
# Also wer großen Hunger hat wird wahrscheinlich nicht zufrieden gestellt.
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Unklar, evtl. bezug auf Portionsgröße/Servicegeschwindigkeit?']
#
#
# Am LOC gelegen, wird hier leckeres Bier und zünftiges Essen serviert.
#  [{'category': 'essen', 'polarity': 'positive'}]
#  ['Unklar ob die Erwähnung der Location hier positiv oder neutral ist.']
#
#
# Das Lokal war trotz Wochenende wirklich schlecht besucht, so hoch wie ich die Preise in Erinnerung hatte, waren sie aber gar nicht.
#  [{'category': 'gesamteindruck', 'polarity': 'neutral'}]
#  ['Unklar, ob Kritik an Preis oder "Lob". Ist "Schlecht besucht" positiv oder negativ?']
#
#
# Die Vorspeise war per sè schön angerichtet und hat auch geschmeckt.... bekamen was anderes als Burrata wegen laktose, danach ging leider der Tiefflug, angehend von der Karte, in einen Sturzflug über.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Unklare Formulierung.']
#
#
# Ist nämlich einfach nur schlechter Stil.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Unklarer Bezug.']
#
#
# Man kann gerne zum Wagner weil es eine urige Kneipe ist, LOC sollte man aber nicht unbedingt.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Bezug unklar, Meinung unklar.']
#
#
# Für diesen Preis trotzdem eine Zumutung.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Unklar, was "eine Zumutung" ist.']
#
#
# LOC der einfachsten Art und dazu ein schlechtes Preis - Leistung Verhältnis.
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['LOC scheint hier aus kontext eine Speise zu sein ("Wiener"?)']
#
#
# Für das Ambiente 4 von 5 Sternen- man kann nichts aussetzten, ist halt Geschmackssache.
#  [{'category': 'ambiente', 'polarity': 'positive'}]
#  ['Meinungsäußerung unklar.']
#
#
# Schade, ansonsten eine sehr schöne Gastronomie mit super netten Service.
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'conflict'}]
#  ['Unklarer Bezug von "Schade", gefolgt von Lob?']
#
#
# Ioulianos Ist super freundlich und gibt tolle Empfehlungen denen wir gerne gefolgt sind.
#  [{'category': 'service', 'polarity': 'positive'}]
#  ['Ich nehme an das Ioulianos ein Kellner ist']
#
#
# Auf nimmer Wiedersehen 👋 Stattdessen haben wir einen super Kaffee im Kaufmanns getrunken😀
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['DIe Bewertung für das eigentliche Restaurant ist negativ, weshalb ich Gesamteindruck-Negativ gewählt habe, trotz das ein super Kaffe erwähnt wurde']
#
#
# Also versuchten wir zu bezahlen, was auch nicht sehr einfach war, weil ca.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Die Bewertung wurde in der Mitte abgeschnitten']
#
#
# Darauf angesprochen, meinte die Bedienung, dass Öl gesund sei........Die aufgerufenen Preise waren absolut überzogen.
#  [{'category': 'preis', 'polarity': 'negative'}]
#  ['Der erste Teil bezieht sich auf den Satz davor']
#
#
# Wir lieben Trüffel, wenn sie hochqualitativ sind.
#  [{'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Ich habe das Gefühl, dass sie bei diesem Restaurant aber nicht hochqualitativ waren']
#
#
# Wir erhielten kleine Teller mit recht überschaubaren Portionen (keine Oliven, die ich bei jeder Art von Griechen erwarte ) Geschmacklich war alles in Ordnung.
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'service', 'polarity': 'negative'}]
#  ['Ich wusste nicht wie ich die kleinen Teller annotieren sollte']
#
#
# Man zahlt zwar etwas mehr, der Service, die nette Bedienung und die Atmosphäre sind es wert!
#  [{'category': 'service', 'polarity': 'positive'}, {'category': 'ambiente', 'polarity': 'positive'}, {'category': 'preis', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'neutral'}]
#  ['Ist das jetzt Preis neutral oder Preis negativ?']
#
#
# Sehr leckeres Bier.
#  [{'category': 'essen', 'polarity': 'conflict'}]
#  ['Essen nicht gleich Trinken']
#
#
# Also versuchten wir zu bezahlen, was auch nicht sehr einfach war, weil ca.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['Unvollständig']
#
#
# Das LOC war ebenfalls trocken und hart und die „LOC“ hatte definitiv auch schon bessere Tage gesehen.
#  [{'category': 'essen', 'polarity': 'negative'}]
#  ['Zweites LOC Lokalname?']
#
#
# Es war das Geld nicht wert.
#  [{'category': 'gesamteindruck', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['Es kann sein, dass es zu teuer oder insgesamt zu schlecht war']
#
#
# Außerdem auch eine sehr gute Weinkarte !
#  [{'category': 'essen', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'positive'}]
#  ['Wegen "Außerdem" scheint der Rest auch gewesen zu sein']
#
#
# Wie immer super qualifizierter Service, leider kam heute die Küche nicht so pünktlich wie sonst immer hinterher.
#  [{'category': 'essen', 'polarity': 'conflict'}, {'category': 'service', 'polarity': 'positive'}]
#  ['Essen kam zu spät, war aber wohl nicht schlecht']
#
#
# Anstatt es einfach auszutauschen wurde mir gesagt, das ich da eben Pech habe.
#  [{'category': 'service', 'polarity': 'negative'}]
#  ['Entweder stimmte was mit dem Essen falsch oder es wurde das falsche Gericht gebracht']
#
#
# Ansonsten eine schöne Location.
#  [{'category': 'ambiente', 'polarity': 'positive'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['"Ansonsten" kann darauf hindeuten, dass es sonst schlecht war']
#
#
# Beispiel 2 : es gab nicht für alle Gäste einen Bierdeckel.
#  [{'category': 'service', 'polarity': 'negative'}, {'category': 'gesamteindruck', 'polarity': 'negative'}]
#  ['da es ein Beispiel ist, ist der Gesamteindruck auch negativ']
#
#
# Auf meine Beschwerde hin wurde mir gesagt, dass das bayrische Bier eben viel Schaum habe.
#  [{'category': 'essen', 'polarity': 'conflict'}, {'category': 'service', 'polarity': 'negative'}]
#  ['Das bayerische Bier hat eben viel Schaum']
#
#
# Die Bedienung hatte wenig Lächeln übrig, war dann wohl bis dann schon ein anstrengender Abend für das Personal.
#  [{'category': 'service', 'polarity': 'neutral'}]
#  ['Schwierig zu entscheiden ob negativ oder neutral, aber da auf den anstrengenden Abend eingegangen wird, für mich eher neutral, da eher eine Feststellung als Kritik']
#
#
# Ein stolzer Preis sollte sich mit einem Stolzen Essen decken!
#  [{'category': 'essen', 'polarity': 'negative'}, {'category': 'preis', 'polarity': 'negative'}]
#  ['In dem Zusammenhang klingt es wie eine Kritik, dass wenn der Preis so hoch ist sollte das Essen auch so gut sein, klingt nicht so, daher negativ']
#
#
#    annotator   K   S  total_choices  comments
# 0      17561   4   4              8         8
# 1       7379  14   8             22        10
# 2      88191  17  17             34         3
# 3      88244  81  17             98         0
# 4      88670  15  15             30         4
# 5      88958  11  12             23         0
# 6      89013  29  17             46         0
# 7      89194   9  29             38        30
# 8      89224   3   4              7         2
# 9      89816   0   1              1         0
# 10     90108  20  13             33        35
# 11     90109  10  13             23        11
# 12     90700   5   3              8         7
# 13     91271   3   4              7         1
# 14     91922   5   3              8         2
# 15      9466  16   2             18         7
# 16      9754  10   8             18         2

# %% [markdown]
# TASD:
#    annotator   K   S  total_choices  comments
# 0      10189  25   8             33        18
# 1      12680   0   0              0         0
# 2      15658   9  17             26         3
# 3      21123   8  12             20         0
# 4      86001   4   0              4         0
# 5      86020   3   4              7         0
# 6      86108   0   0              0         1
# 7      86407   0   0              0         0
# 8      86725  17  10             27         1
# 9      87069  14   5             19        19
# 10     87560   0   3              3         0
# 11     87576   8  16             24         1
# 12     88190   4   5              9         3
# 13     88285   8   5             13         4
# 14     89770   5   0              5         0

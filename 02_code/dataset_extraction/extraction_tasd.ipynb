# %% [markdown]
# # Extraction of single Student Annotations

# %%
import json
from collections import defaultdict

# Define valid categories and polarities (with English mapping)
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities_map = {
    "negativ": "negative",
    "positiv": "positive",
    "neutral": "neutral",
    "konflikt": "conflict",
    "NULL": "NULL"
}

# Load JSON file
with open("data/15_anno_train_crowd.json", "r", encoding="utf-8") as f:
    data = json.load(f)

annotator_data = defaultdict(list)

# Process data
for item in data:
    task_data = item.get("data", {})
    task_id = task_data.get("id")
    original_id = task_data.get("original_id", task_id)
    text = task_data.get("text", "")

    for ann in item.get("annotations", []):
        completed_by = ann.get("completed_by")
        result_map = {}

        for result in ann.get("result", []):
            rid = result.get("id")
            if rid not in result_map:
                result_map[rid] = {"explicit": [], "implicit": False}

            from_name = result.get("from_name")
            val = result.get("value", {})

            if from_name == "category_polarity":
                for lbl in val.get("labels", []):
                    parts = lbl.split("-")
                    category = parts[0].lower()
                    print(category)
                    polarity = parts[1].lower() if len(parts) > 1 else "NULL"
                    result_map[rid]["explicit"].append([category, polarity, val.get("text", "NULL")])
            elif from_name == "implicit":
                result_map[rid]["implicit"] = True

        labels_list = []
        for res in result_map.values():
            for lbl in res["explicit"]:
                if res["implicit"]:
                    lbl[2] = "NULL"
                # Translate polarity to English
                lbl[1] = valid_polarities_map.get(lbl[1], lbl[1])
                labels_list.append(lbl)

        if labels_list:
            annotator_data[completed_by].append({
                "id": str(task_id),
                "original_id": str(original_id),
                "text": text,
                "labels": labels_list
            })

# Validation and saving
for annotator, entries in annotator_data.items():
    filename = f"results_crowd/{annotator}.jsonl"
    with open(filename, "w", encoding="utf-8") as f:
        for entry in entries:
            json.dump(entry, f, ensure_ascii=False)
            f.write("\n")

    # Checks
    if len(entries) != 200:
        # print(f"Length Error: Annotator {annotator} has {len(entries)} entries, expected 200.")
        None

    for entry in entries:
        for lbl in entry["labels"]:
            category, polarity, phrase = lbl
            # Check category
            if category not in valid_categories:
                print(f"Category Error in annotator {annotator}, id {entry['id']}: invalid category '{category}'")
            # Check polarity
            if polarity not in {"negative", "positive", "neutral", "conflict", "NULL"}:
                print(f"Polarity Error in annotator {annotator}, id {entry['id']}: invalid polarity '{polarity}'")
            # Check phrase exists in text if not NULL
            if phrase != "NULL" and phrase not in entry["text"]:
                print(f"Phrase Error in annotator {annotator}, id {entry['id']}: phrase '{phrase}' not in text")

print("Processing and validation complete.")
# Out:
# essen
# essen
# essen
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# preis
# preis
# preis
# essen
# service
# essen
# service
# essen
# service
# service
# service
# service
# service
# service
# service
# preis
# preis
# preis
# preis
# preis
# preis
# preis
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# service
# essen
# service
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# preis
# service
# preis
# essen
# gesamteindruck
# preis
# ambiente
# service
# ambiente
# service
# service
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# essen
# service
# essen
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# preis
# preis
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# essen
# ambiente
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# service
# essen
# essen
# service
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# gesamteindruck
# service
# essen
# gesamteindruck
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# ambiente
# ambiente
# service
# service
# service
# essen
# essen
# gesamteindruck
# ambiente
# service
# service
# service
# essen
# gesamteindruck
# ambiente
# essen
# service
# ambiente
# ambiente
# ambiente
# essen
# service
# essen
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# service
# essen
# gesamteindruck
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# service
# essen
# service
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# service
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# essen
# service
# essen
# service
# essen
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# preis
# essen
# preis
# essen
# preis
# ambiente
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# essen
# preis
# preis
# essen
# service
# service
# service
# service
# service
# service
# ambiente
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# service
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# service
# service
# service
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# service
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# service
# essen
# ambiente
# essen
# service
# ambiente
# service
# essen
# ambiente
# ambiente
# service
# ambiente
# ambiente
# service
# ambiente
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# essen
# service
# ambiente
# service
# service
# service
# ambiente
# ambiente
# ambiente
# preis
# preis
# preis
# essen
# essen
# essen
# service
# preis
# essen
# essen
# preis
# preis
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# essen
# essen
# essen
# preis
# essen
# essen
# essen
# preis
# service
# essen
# service
# essen
# service
# service
# essen
# essen
# ambiente
# essen
# ambiente
# essen
# ambiente
# service
# essen
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# essen
# ambiente
# essen
# ambiente
# gesamteindruck
# service
# service
# service
# service
# essen
# service
# essen
# service
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# service
# service
# essen
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# essen
# service
# essen
# service
# essen
# service
# essen
# service
# service
# essen
# service
# essen
# essen
# service
# service
# essen
# service
# essen
# ambiente
# essen
# ambiente
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# gesamteindruck
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# preis
# preis
# preis
# ambiente
# gesamteindruck
# service
# essen
# ambiente
# ambiente
# essen
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# ambiente
# gesamteindruck
# essen
# essen
# essen
# essen
# preis
# ambiente
# essen
# essen
# essen
# preis
# ambiente
# essen
# essen
# essen
# preis
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# preis
# preis
# preis
# ambiente
# service
# essen
# essen
# service
# service
# ambiente
# service
# essen
# service
# essen
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# service
# ambiente
# ambiente
# service
# ambiente
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# service
# service
# essen
# ambiente
# essen
# ambiente
# service
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# essen
# essen
# service
# essen
# ambiente
# ambiente
# ambiente
# essen
# gesamteindruck
# ambiente
# essen
# gesamteindruck
# ambiente
# service
# essen
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# essen
# service
# service
# service
# service
# service
# ambiente
# essen
# service
# ambiente
# essen
# service
# ambiente
# service
# essen
# essen
# essen
# service
# essen
# preis
# essen
# preis
# preis
# essen
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# service
# service
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# service
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# essen
# essen
# essen
# ambiente
# essen
# ambiente
# essen
# ambiente
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# gesamteindruck
# service
# gesamteindruck
# service
# essen
# essen
# essen
# essen
# service
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# service
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# service
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# service
# gesamteindruck
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# essen
# essen
# service
# essen
# service
# ambiente
# essen
# essen
# gesamteindruck
# essen
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# service
# service
# service
# service
# essen
# service
# service
# essen
# service
# essen
# essen
# essen
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# service
# service
# essen
# ambiente
# essen
# ambiente
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# essen
# essen
# preis
# preis
# essen
# preis
# service
# service
# service
# service
# service
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# preis
# essen
# essen
# preis
# preis
# preis
# essen
# essen
# essen
# preis
# preis
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# service
# service
# preis
# service
# essen
# service
# essen
# service
# essen
# service
# ambiente
# essen
# ambiente
# essen
# ambiente
# essen
# ambiente
# preis
# gesamteindruck
# ambiente
# preis
# service
# ambiente
# service
# preis
# service
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# ambiente
# gesamteindruck
# ambiente
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# service
# gesamteindruck
# service
# essen
# essen
# ambiente
# essen
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# ambiente
# service
# service
# ambiente
# gesamteindruck
# service
# gesamteindruck
# ambiente
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# service
# gesamteindruck
# ambiente
# essen
# service
# service
# service
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# essen
# service
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# gesamteindruck
# service
# ambiente
# essen
# service
# service
# essen
# essen
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# essen
# gesamteindruck
# essen
# essen
# preis
# essen
# preis
# preis
# essen
# preis
# service
# service
# service
# service
# gesamteindruck
# service
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# ambiente
# service
# essen
# essen
# service
# gesamteindruck
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# service
# essen
# service
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# preis
# preis
# preis
# essen
# preis
# preis
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# preis
# service
# service
# essen
# preis
# service
# essen
# preis
# ambiente
# service
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# service
# essen
# ambiente
# service
# essen
# ambiente
# service
# ambiente
# preis
# preis
# preis
# preis
# ambiente
# gesamteindruck
# ambiente
# gesamteindruck
# ambiente
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# essen
# essen
# essen
# service
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# essen
# service
# essen
# service
# preis
# preis
# preis
# preis
# ambiente
# ambiente
# ambiente
# essen
# gesamteindruck
# essen
# essen
# service
# preis
# service
# service
# service
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# essen
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# gesamteindruck
# service
# gesamteindruck
# ambiente
# service
# service
# gesamteindruck
# service
# service
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# ambiente
# ambiente
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# preis
# preis
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# service
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# service
# service
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# service
# preis
# service
# gesamteindruck
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# service
# ambiente
# service
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# essen
# essen
# service
# service
# service
# essen
# service
# service
# service
# essen
# service
# service
# service
# service
# service
# service
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# service
# service
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# service
# ambiente
# service
# ambiente
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# essen
# essen
# essen
# essen
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# service
# essen
# preis
# essen
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# preis
# essen
# essen
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# essen
# service
# essen
# service
# preis
# preis
# essen
# essen
# service
# service
# service
# service
# essen
# essen
# service
# gesamteindruck
# essen
# essen
# service
# preis
# preis
# service
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# ambiente
# essen
# essen
# gesamteindruck
# essen
# essen
# service
# service
# service
# essen
# essen
# service
# service
# service
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# service
# service
# service
# service
# essen
# essen
# service
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# service
# service
# service
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# service
# essen
# essen
# gesamteindruck
# gesamteindruck
# preis
# service
# gesamteindruck
# preis
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# essen
# service
# service
# service
# essen
# essen
# service
# service
# ambiente
# ambiente
# gesamteindruck
# ambiente
# service
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# gesamteindruck
# essen
# ambiente
# service
# ambiente
# essen
# ambiente
# preis
# preis
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# essen
# essen
# ambiente
# essen
# essen
# essen
# ambiente
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# preis
# preis
# preis
# service
# service
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# preis
# gesamteindruck
# preis
# preis
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# essen
# preis
# service
# service
# service
# essen
# essen
# essen
# service
# essen
# gesamteindruck
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# essen
# preis
# service
# service
# service
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# gesamteindruck
# ambiente
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# service
# service
# service
# service
# service
# essen
# essen
# essen
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# essen
# service
# service
# essen
# service
# service
# essen
# essen
# ambiente
# ambiente
# service
# ambiente
# essen
# service
# essen
# ambiente
# service
# service
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# ambiente
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# service
# service
# service
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# essen
# essen
# service
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# gesamteindruck
# essen
# essen
# service
# service
# service
# service
# preis
# service
# essen
# preis
# essen
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# essen
# service
# essen
# service
# service
# service
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# essen
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# essen
# essen
# service
# service
# essen
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# essen
# service
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# ambiente
# gesamteindruck
# essen
# service
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# gesamteindruck
# gesamteindruck
# essen
# service
# essen
# service
# essen
# service
# service
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# gesamteindruck
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# essen
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# service
# service
# essen
# service
# essen
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# gesamteindruck
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# essen
# essen
# service
# service
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# service
# service
# service
# service
# preis
# preis
# preis
# preis
# preis
# service
# service
# preis
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# service
# service
# service
# gesamteindruck
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# service
# service
# service
# essen
# ambiente
# service
# essen
# ambiente
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# essen
# ambiente
# essen
# essen
# service
# service
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# service
# service
# service
# essen
# service
# service
# service
# essen
# essen
# service
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# essen
# service
# essen
# ambiente
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# essen
# service
# service
# service
# preis
# essen
# preis
# preis
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# essen
# preis
# essen
# essen
# preis
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# preis
# service
# service
# service
# service
# preis
# preis
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# service
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# ambiente
# service
# service
# service
# essen
# ambiente
# ambiente
# ambiente
# service
# essen
# ambiente
# service
# essen
# ambiente
# preis
# preis
# preis
# service
# service
# service
# ambiente
# gesamteindruck
# service
# ambiente
# gesamteindruck
# preis
# preis
# service
# service
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# service
# gesamteindruck
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# service
# gesamteindruck
# preis
# essen
# preis
# essen
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# gesamteindruck
# gesamteindruck
# preis
# preis
# ambiente
# essen
# gesamteindruck
# essen
# essen
# essen
# service
# service
# gesamteindruck
# service
# service
# essen
# essen
# service
# gesamteindruck
# essen
# essen
# ambiente
# essen
# essen
# ambiente
# service
# essen
# preis
# preis
# ambiente
# ambiente
# essen
# essen
# service
# ambiente
# service
# essen
# preis
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# ambiente
# service
# essen
# ambiente
# service
# essen
# ambiente
# service
# essen
# service
# essen
# essen
# service
# service
# service
# ambiente
# gesamteindruck
# gesamteindruck
# preis
# gesamteindruck
# preis
# gesamteindruck
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# preis
# essen
# preis
# essen
# preis
# essen
# preis
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# ambiente
# essen
# essen
# essen
# ambiente
# essen
# essen
# ambiente
# essen
# ambiente
# essen
# essen
# ambiente
# essen
# service
# essen
# essen
# essen
# essen
# service
# essen
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# ambiente
# service
# service
# service
# service
# essen
# service
# service
# service
# essen
# service
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# ambiente
# service
# service
# service
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# ambiente
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# essen
# service
# gesamteindruck
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# service
# service
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# preis
# preis
# preis
# preis
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# essen
# service
# essen
# service
# ambiente
# gesamteindruck
# ambiente
# gesamteindruck
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# ambiente
# ambiente
# ambiente
# service
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# service
# service
# service
# service
# essen
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# essen
# ambiente
# ambiente
# essen
# ambiente
# ambiente
# gesamteindruck
# ambiente
# ambiente
# ambiente
# service
# ambiente
# gesamteindruck
# service
# ambiente
# service
# ambiente
# service
# gesamteindruck
# gesamteindruck
# service
# service
# service
# gesamteindruck
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# service
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# service
# essen
# essen
# essen
# service
# service
# service
# service
# ambiente
# service
# service
# service
# service
# essen
# service
# service
# service
# service
# service
# ambiente
# gesamteindruck
# essen
# gesamteindruck
# ambiente
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# gesamteindruck
# service
# essen
# service
# essen
# essen
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# preis
# preis
# preis
# service
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# ambiente
# service
# essen
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# service
# essen
# ambiente
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# service
# ambiente
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# ambiente
# service
# essen
# ambiente
# preis
# gesamteindruck
# ambiente
# service
# essen
# gesamteindruck
# ambiente
# service
# essen
# preis
# ambiente
# service
# ambiente
# service
# ambiente
# service
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# gesamteindruck
# preis
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# ambiente
# essen
# essen
# preis
# essen
# preis
# ambiente
# essen
# essen
# ambiente
# preis
# essen
# service
# essen
# service
# essen
# essen
# service
# essen
# gesamteindruck
# essen
# essen
# preis
# preis
# preis
# service
# service
# service
# service
# service
# essen
# service
# service
# service
# service
# preis
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# service
# essen
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# gesamteindruck
# service
# essen
# service
# essen
# gesamteindruck
# gesamteindruck
# essen
# service
# gesamteindruck
# ambiente
# essen
# service
# service
# ambiente
# essen
# service
# service
# service
# service
# service
# service
# service
# preis
# essen
# essen
# preis
# essen
# preis
# service
# service
# service
# service
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# service
# essen
# service
# essen
# service
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# service
# service
# essen
# essen
# service
# essen
# service
# essen
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# ambiente
# preis
# ambiente
# preis
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# preis
# essen
# preis
# essen
# preis
# essen
# essen
# ambiente
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# essen
# essen
# ambiente
# essen
# essen
# essen
# essen
# essen
# service
# ambiente
# gesamteindruck
# service
# service
# service
# service
# essen
# preis
# essen
# preis
# service
# service
# essen
# preis
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# gesamteindruck
# service
# service
# service
# gesamteindruck
# service
# service
# service
# service
# essen
# preis
# essen
# preis
# essen
# preis
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# essen
# essen
# essen
# service
# gesamteindruck
# service
# gesamteindruck
# service
# essen
# essen
# essen
# ambiente
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# essen
# essen
# essen
# essen
# preis
# preis
# essen
# essen
# preis
# essen
# preis
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# service
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# ambiente
# gesamteindruck
# service
# gesamteindruck
# service
# gesamteindruck
# service
# service
# essen
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# service
# service
# service
# service
# service
# ambiente
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# ambiente
# essen
# essen
# ambiente
# ambiente
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# essen
# service
# service
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# ambiente
# ambiente
# service
# service
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# service
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# preis
# essen
# preis
# essen
# preis
# service
# service
# gesamteindruck
# service
# ambiente
# service
# ambiente
# service
# ambiente
# ambiente
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# service
# essen
# service
# ambiente
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# essen
# gesamteindruck
# implizit
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# essen
# essen
# essen
# ambiente
# ambiente
# implizit
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# gesamteindruck
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# ambiente
# essen
# ambiente
# essen
# ambiente
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# service
# essen
# preis
# ambiente
# service
# essen
# ambiente
# ambiente
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# ambiente
# service
# essen
# ambiente
# service
# essen
# essen
# essen
# service
# ambiente
# service
# service
# service
# service
# service
# service
# essen
# service
# implizit
# essen
# essen
# essen
# essen
# essen
# essen
# implizit
# essen
# essen
# service
# service
# service
# service
# service
# service
# gesamteindruck
# service
# service
# service
# service
# service
# service
# ambiente
# service
# ambiente
# service
# ambiente
# service
# ambiente
# ambiente
# essen
# gesamteindruck
# essen
# essen
# gesamteindruck
# implizit
# essen
# gesamteindruck
# ambiente
# essen
# service
# ambiente
# essen
# service
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# service
# service
# ambiente
# gesamteindruck
# essen
# service
# essen
# service
# service
# essen
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# implizit
# essen
# essen
# essen
# essen
# preis
# essen
# preis
# preis
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# essen
# implizit
# service
# essen
# essen
# essen
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# ambiente
# service
# implizit
# essen
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# preis
# preis
# gesamteindruck
# preis
# ambiente
# preis
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# implizit
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# implizit
# essen
# gesamteindruck
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# essen
# ambiente
# ambiente
# essen
# essen
# essen
# preis
# preis
# preis
# essen
# preis
# preis
# preis
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# implizit
# service
# implizit
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# implizit
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# service
# essen
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# implizit
# service
# service
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# preis
# preis
# ambiente
# essen
# service
# service
# essen
# preis
# ambiente
# essen
# service
# essen
# preis
# ambiente
# essen
# service
# service
# service
# preis
# essen
# implizit
# preis
# implizit
# preis
# essen
# preis
# gesamteindruck
# ambiente
# service
# implizit
# service
# ambiente
# service
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# gesamteindruck
# essen
# service
# ambiente
# preis
# service
# service
# service
# service
# service
# service
# preis
# preis
# gesamteindruck
# implizit
# preis
# preis
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# ambiente
# ambiente
# gesamteindruck
# ambiente
# ambiente
# ambiente
# service
# service
# implizit
# service
# service
# preis
# preis
# preis
# preis
# preis
# preis
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# service
# preis
# essen
# service
# preis
# preis
# essen
# service
# service
# preis
# preis
# preis
# preis
# gesamteindruck
# implizit
# preis
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# ambiente
# gesamteindruck
# implizit
# ambiente
# ambiente
# essen
# gesamteindruck
# implizit
# essen
# essen
# essen
# service
# implizit
# essen
# essen
# essen
# essen
# preis
# essen
# preis
# essen
# preis
# essen
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# preis
# ambiente
# ambiente
# ambiente
# essen
# ambiente
# ambiente
# essen
# ambiente
# service
# essen
# essen
# gesamteindruck
# service
# service
# implizit
# preis
# preis
# service
# service
# implizit
# service
# service
# gesamteindruck
# gesamteindruck
# service
# service
# implizit
# service
# service
# service
# service
# service
# service
# service
# service
# service
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# ambiente
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# implizit
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# service
# service
# preis
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# service
# service
# service
# service
# preis
# preis
# gesamteindruck
# gesamteindruck
# implizit
# essen
# service
# ambiente
# gesamteindruck
# preis
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# ambiente
# service
# essen
# preis
# gesamteindruck
# service
# service
# service
# essen
# essen
# essen
# essen
# preis
# gesamteindruck
# implizit
# preis
# gesamteindruck
# service
# service
# essen
# service
# essen
# service
# service
# essen
# essen
# essen
# essen
# service
# implizit
# service
# essen
# service
# ambiente
# gesamteindruck
# service
# service
# gesamteindruck
# ambiente
# gesamteindruck
# service
# ambiente
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# ambiente
# ambiente
# implizit
# ambiente
# ambiente
# preis
# gesamteindruck
# preis
# ambiente
# implizit
# preis
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# essen
# gesamteindruck
# service
# gesamteindruck
# implizit
# service
# service
# essen
# essen
# service
# implizit
# essen
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# ambiente
# essen
# service
# ambiente
# essen
# essen
# service
# service
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# service
# service
# service
# service
# preis
# service
# ambiente
# preis
# service
# ambiente
# service
# service
# preis
# preis
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# ambiente
# essen
# gesamteindruck
# essen
# service
# essen
# essen
# gesamteindruck
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# gesamteindruck
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# implizit
# gesamteindruck
# gesamteindruck
# ambiente
# service
# gesamteindruck
# gesamteindruck
# service
# ambiente
# ambiente
# gesamteindruck
# service
# service
# service
# service
# ambiente
# service
# ambiente
# service
# ambiente
# essen
# essen
# service
# essen
# essen
# gesamteindruck
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# ambiente
# service
# service
# ambiente
# service
# ambiente
# ambiente
# service
# service
# service
# service
# service
# gesamteindruck
# gesamteindruck
# ambiente
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# service
# essen
# essen
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# ambiente
# essen
# ambiente
# ambiente
# essen
# ambiente
# ambiente
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# service
# service
# essen
# essen
# ambiente
# ambiente
# essen
# ambiente
# service
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# essen
# service
# service
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# essen
# service
# essen
# service
# essen
# service
# service
# service
# service
# service
# service
# service
# service
# service
# service
# essen
# service
# essen
# service
# service
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# essen
# service
# service
# ambiente
# ambiente
# service
# ambiente
# ambiente
# service
# service
# service
# service
# essen
# essen
# essen
# essen
# gesamteindruck
# gesamteindruck
# gesamteindruck
# service
# gesamteindruck
# service
# gesamteindruck
# service
# gesamteindruck
# gesamteindruck
# gesamteindruck
# gesamteindruck
# Phrase Error in annotator 91948, id 45: phrase 'ein toller früher Silvesterabend.\n\n' not in text
# Phrase Error in annotator 91948, id 57: phrase 'Wir kommen gerne wieder.\n\n' not in text
# Phrase Error in annotator 91948, id 64: phrase 'Schade!\n\n' not in text
# Phrase Error in annotator 91948, id 74: phrase 'Nichts konnte überzeugen.\n\n' not in text
# Phrase Error in annotator 91948, id 78: phrase 'Was soll ich sagen , einfach genial!\n\n' not in text
# Phrase Error in annotator 91948, id 84: phrase 'Wäre in LOC Mittelklasse.\n\n' not in text
# Phrase Error in annotator 91948, id 102: phrase 'Das war der letzte Besuch!\n\n' not in text
# Phrase Error in annotator 91948, id 130: phrase 'Dafür nochmals herzlichen Dank.\n\n' not in text
# Phrase Error in annotator 91948, id 153: phrase 'Sehr gutes LOC.\n\n' not in text
# Phrase Error in annotator 91948, id 187: phrase '- Es war schon mal deutlich besser.\n\n' not in text
# Phrase Error in annotator 91954, id 285: phrase 'Service.\n' not in text
# Phrase Error in annotator 91951, id 764: phrase 'nicht gut.\n\n' not in text
# Category Error in annotator 91947, id 807: invalid category 'implizit'
# Category Error in annotator 91947, id 808: invalid category 'implizit'
# Category Error in annotator 91947, id 809: invalid category 'implizit'
# Category Error in annotator 91947, id 811: invalid category 'implizit'
# Category Error in annotator 91947, id 812: invalid category 'implizit'
# Category Error in annotator 91947, id 819: invalid category 'implizit'
# Category Error in annotator 91947, id 826: invalid category 'implizit'
# Category Error in annotator 91947, id 827: invalid category 'implizit'
# Category Error in annotator 91947, id 831: invalid category 'implizit'
# Category Error in annotator 91947, id 835: invalid category 'implizit'
# Category Error in annotator 91947, id 841: invalid category 'implizit'
# Category Error in annotator 91947, id 844: invalid category 'implizit'
# Category Error in annotator 91947, id 849: invalid category 'implizit'
# Category Error in annotator 91947, id 851: invalid category 'implizit'
# Category Error in annotator 91947, id 854: invalid category 'implizit'
# Category Error in annotator 91947, id 855: invalid category 'implizit'
# Category Error in annotator 91947, id 856: invalid category 'implizit'
# Category Error in annotator 91947, id 860: invalid category 'implizit'
# Category Error in annotator 91947, id 860: invalid category 'implizit'
# Category Error in annotator 91947, id 863: invalid category 'implizit'
# Category Error in annotator 91947, id 865: invalid category 'implizit'
# Category Error in annotator 91947, id 870: invalid category 'implizit'
# Category Error in annotator 91947, id 870: invalid category 'implizit'
# Category Error in annotator 91947, id 871: invalid category 'implizit'
# Category Error in annotator 91947, id 875: invalid category 'implizit'
# Category Error in annotator 91947, id 879: invalid category 'implizit'
# Category Error in annotator 91947, id 882: invalid category 'implizit'
# Category Error in annotator 91947, id 886: invalid category 'implizit'
# Category Error in annotator 91947, id 890: invalid category 'implizit'
# Category Error in annotator 91947, id 891: invalid category 'implizit'
# Category Error in annotator 91947, id 891: invalid category 'implizit'
# Category Error in annotator 91947, id 893: invalid category 'implizit'
# Category Error in annotator 91947, id 894: invalid category 'implizit'
# Category Error in annotator 91947, id 895: invalid category 'implizit'
# Category Error in annotator 91947, id 900: invalid category 'implizit'
# Category Error in annotator 91947, id 902: invalid category 'implizit'
# Category Error in annotator 91947, id 905: invalid category 'implizit'
# Category Error in annotator 91947, id 906: invalid category 'implizit'
# Category Error in annotator 91947, id 907: invalid category 'implizit'
# Category Error in annotator 91947, id 910: invalid category 'implizit'
# Category Error in annotator 91947, id 913: invalid category 'implizit'
# Category Error in annotator 91947, id 914: invalid category 'implizit'
# Category Error in annotator 91947, id 915: invalid category 'implizit'
# Category Error in annotator 91947, id 917: invalid category 'implizit'
# Category Error in annotator 91947, id 920: invalid category 'implizit'
# Category Error in annotator 91947, id 923: invalid category 'implizit'
# Category Error in annotator 91947, id 925: invalid category 'implizit'
# Category Error in annotator 91947, id 929: invalid category 'implizit'
# Category Error in annotator 91947, id 933: invalid category 'implizit'
# Category Error in annotator 91947, id 934: invalid category 'implizit'
# Category Error in annotator 91947, id 935: invalid category 'implizit'
# Category Error in annotator 91947, id 938: invalid category 'implizit'
# Category Error in annotator 91947, id 939: invalid category 'implizit'
# Category Error in annotator 91947, id 942: invalid category 'implizit'
# Category Error in annotator 91947, id 949: invalid category 'implizit'
# Category Error in annotator 91947, id 958: invalid category 'implizit'
# Category Error in annotator 91947, id 963: invalid category 'implizit'
# Phrase Error in annotator 91957, id 807: phrase 'Kommen sicher wieder.\n' not in text
# Phrase Error in annotator 91957, id 819: phrase 'kommen gerne wieder\n' not in text
# Phrase Error in annotator 91957, id 862: phrase 'wenig Abstand zwischen den Tischen.\n' not in text
# Phrase Error in annotator 91957, id 914: phrase 'Immer wieder gerne!!!\n' not in text
# Phrase Error in annotator 91957, id 914: phrase 'Immer wieder gerne!!!\n' not in text
# Phrase Error in annotator 91957, id 915: phrase 'Bald wieder!\n' not in text
# Phrase Error in annotator 91957, id 917: phrase 'Unverschämtheit.\n' not in text
# Phrase Error in annotator 91957, id 917: phrase 'Unverschämtheit.\n' not in text
# Phrase Error in annotator 91957, id 965: phrase 'freundlich und speditiv.\n' not in text
# Phrase Error in annotator 91957, id 993: phrase 'Es war ein rundum gelungener Abend.\n' not in text
# Phrase Error in annotator 91957, id 997: phrase 'Wir hatten zwei wunderschöne Abende und alles hat gepasst.\n' not in text
# Processing and validation complete.

# %% [markdown]
# ## Add missing entries

# %%
#!/usr/bin/env python3
import json
import os
import glob
from collections import Counter, defaultdict

# Config
RESULTS_DIR = "results_crowd"       # where annotator jsonl files live
TRAINSET_FILE = "data/trainset_1000.jsonl"
SPLIT_SIZE = 200                      # split size (0-199,200-399,...)
NUM_SPLITS = 5                        # 1000 / 200

def load_trainset(path):
    train = []
    id_to_index = {}
    with open(path, "r", encoding="utf-8") as f:
        for idx, line in enumerate(f):
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
            except json.JSONDecodeError as e:
                raise RuntimeError(f"Error parsing trainset line {idx}: {e}")
            train.append(obj)
            id_to_index[str(obj.get("id"))] = idx
    return train, id_to_index

def load_jsonl(path):
    items = []
    with open(path, "r", encoding="utf-8") as f:
        for line_no, line in enumerate(f, 1):
            s = line.strip()
            if not s:
                continue
            try:
                obj = json.loads(s)
            except json.JSONDecodeError as e:
                raise RuntimeError(f"Error parsing {path} line {line_no}: {e}")
            items.append(obj)
    return items

def write_jsonl(path, items):
    with open(path, "w", encoding="utf-8") as f:
        for obj in items:
            json.dump(obj, f, ensure_ascii=False)
            f.write("\n")

def detect_split(present_ids, id_to_index):
    # Count which split each id falls into (based on trainset index)
    split_counts = Counter()
    missing_ids = []
    for pid in present_ids:
        idx = id_to_index.get(pid)
        if idx is None:
            missing_ids.append(pid)
        else:
            split = idx // SPLIT_SIZE
            split_counts[split] += 1
    if not split_counts:
        # No match at all -> default to split 0 and report
        return 0, missing_ids
    best_split = max(split_counts.items(), key=lambda x: (x[1], -x[0]))[0]
    return best_split, missing_ids

def complete_file(file_path, trainset, id_to_index):
    # Load annotator file
    items = load_jsonl(file_path)
    present_map = {str(item.get("id")): item for item in items}
    present_ids = list(present_map.keys())

    best_split, not_found_in_train = detect_split(present_ids, id_to_index)

    start = best_split * SPLIT_SIZE
    end = start + SPLIT_SIZE
    split_train = trainset[start:end]

    train_ids_in_split = [str(x.get("id")) for x in split_train]

    # Build final list in trainset order: either existing annotator entry or filled entry
    final_entries = []
    added_ids = []
    kept_ids = []
    for ts in split_train:
        ts_id_str = str(ts.get("id"))
        if ts_id_str in present_map:
            # Keep annotator's entry, but ensure it contains original_id and text (fill from trainset if missing)
            entry = present_map[ts_id_str]
            if "original_id" not in entry and "original_id" in ts:
                entry["original_id"] = ts.get("original_id")
            if "text" not in entry and "text" in ts:
                entry["text"] = ts.get("text")
            # If this annotator entry is missing labels key, preserve it (do not auto-insert)
            if "labels" not in entry:
                entry["labels"] = []
            final_entries.append(entry)
            kept_ids.append(ts_id_str)
        else:
            # Create missing entry using trainset entry + empty labels
            new_entry = {
                "id": str(ts.get("id")),
                "original_id": str(ts.get("original_id")),
                "text": ts.get("text"),
                "labels": []
            }
            final_entries.append(new_entry)
            added_ids.append(ts_id_str)

    # Any present entries outside the chosen split will be reported and dropped
    outsiders = [pid for pid in present_ids if pid not in set(train_ids_in_split)]

    # Final safety checks
    if len(final_entries) != SPLIT_SIZE:
        raise RuntimeError(f"Internal error: final_entries length is {len(final_entries)} (expected {SPLIT_SIZE}) for file {file_path}")

    # Overwrite file
    write_jsonl(file_path, final_entries)

    summary = {
        "file": file_path,
        "chosen_split": (start, end-1),
        "kept_count": len(kept_ids),
        "added_count": len(added_ids),
        "added_ids": added_ids,
        "outsiders_dropped": outsiders,
        "ids_not_found_in_trainset": not_found_in_train
    }
    return summary

def main():
    if not os.path.exists(TRAINSET_FILE):
        print(f"Trainset file not found: {TRAINSET_FILE}")
        return

    trainset, id_to_index = load_trainset(TRAINSET_FILE)

    files = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.jsonl")))
    if not files:
        print(f"No .jsonl files found in {RESULTS_DIR}")
        return

    all_summaries = []
    for fpath in files:
        try:
            summary = complete_file(fpath, trainset, id_to_index)
            all_summaries.append(summary)
            print(f"Processed {os.path.basename(fpath)}: split {summary['chosen_split'][0]}-{summary['chosen_split'][1]}, "
                  f"kept {summary['kept_count']}, added {summary['added_count']}, dropped outsiders {len(summary['outsiders_dropped'])}")
            if summary["outsiders_dropped"]:
                print("  -> Dropped outsider ids (not in chosen split):", summary["outsiders_dropped"])
            if summary["ids_not_found_in_trainset"]:
                print("  -> IDs present in file but not found in trainset:", summary["ids_not_found_in_trainset"])
        except Exception as e:
            print(f"Error processing {fpath}: {e}")

    # Optionally write a summary JSON
    summary_path = os.path.join(RESULTS_DIR, "fill_summary.json")
    with open(summary_path, "w", encoding="utf-8") as sf:
        json.dump(all_summaries, sf, ensure_ascii=False, indent=2)

    print(f"\nDone. Summary saved to {summary_path}")

if __name__ == "__main__":
    main()
# Out:
# Processed 91942.jsonl: split 0-199, kept 192, added 8, dropped outsiders 0
# Processed 91943.jsonl: split 200-399, kept 192, added 8, dropped outsiders 0
# Processed 91946.jsonl: split 600-799, kept 200, added 0, dropped outsiders 0
# Processed 91947.jsonl: split 800-999, kept 200, added 0, dropped outsiders 0
# Processed 91948.jsonl: split 0-199, kept 200, added 0, dropped outsiders 0
# Processed 91949.jsonl: split 200-399, kept 200, added 0, dropped outsiders 0
# Processed 91950.jsonl: split 400-599, kept 200, added 0, dropped outsiders 0
# Processed 91951.jsonl: split 600-799, kept 199, added 1, dropped outsiders 0
# Processed 91954.jsonl: split 200-399, kept 200, added 0, dropped outsiders 0
# Processed 91956.jsonl: split 600-799, kept 199, added 1, dropped outsiders 0
# Processed 91957.jsonl: split 800-999, kept 200, added 0, dropped outsiders 0
# Processed 97366.jsonl: split 400-599, kept 200, added 0, dropped outsiders 0
# Processed 97367.jsonl: split 0-199, kept 199, added 1, dropped outsiders 0
# Processed 97368.jsonl: split 400-599, kept 197, added 3, dropped outsiders 0
# Processed 97533.jsonl: split 800-999, kept 195, added 5, dropped outsiders 0
#
# Done. Summary saved to results_crowd\fill_summary.json

# %% [markdown]
# ## Check files

# %%
import os
import json
import glob

# Folders
RESULTS_DIR = "results_crowd"

# Validation sets
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities = {"negative", "positive", "neutral", "conflict", "NULL"}

def load_jsonl(path):
    entries = []
    with open(path, "r", encoding="utf-8") as f:
        for line_no, line in enumerate(f, 1):
            s = line.strip()
            if not s:
                continue
            try:
                obj = json.loads(s)
            except json.JSONDecodeError as e:
                print(f"JSON error in {path}, line {line_no}: {e}")
                continue
            entries.append(obj)
    return entries

def validate_file(path):
    annotator = os.path.basename(path).replace(".jsonl", "")
    entries = load_jsonl(path)

    # Check file length
    if len(entries) != 200:
        print("Length!")
        None

    # Check each entry
    for entry in entries:
        for lbl in entry.get("labels", []):
            if not lbl:
                continue
            if len(lbl) != 3:
                print(f"Format Error in {annotator}, id {entry['id']}: label {lbl} is not triplet")
                continue
            category, polarity, phrase = lbl

            # Category check
            if category not in valid_categories:
                print(f"Category Error in {annotator}, id {entry['id']}: invalid category '{category}'")

            # Polarity check
            if polarity not in valid_polarities:
                print(f"Polarity Error in {annotator}, id {entry['id']}: invalid polarity '{polarity}'")

            # Phrase check
            if phrase != "NULL" and phrase not in entry.get("text", ""):
                print(f"Phrase Error in {annotator}, id {entry['id']}: phrase '{phrase}' not in text")

def main():
    files = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.jsonl")))
    if not files:
        print(f"No .jsonl files found in {RESULTS_DIR}")
        return

    for path in files:
        validate_file(path)

    print("Processing and validation complete.")

if __name__ == "__main__":
    main()
# Out:
# Phrase Error in 91948, id 45: phrase 'ein toller früher Silvesterabend.\n\n' not in text
# Phrase Error in 91948, id 57: phrase 'Wir kommen gerne wieder.\n\n' not in text
# Phrase Error in 91948, id 64: phrase 'Schade!\n\n' not in text
# Phrase Error in 91948, id 74: phrase 'Nichts konnte überzeugen.\n\n' not in text
# Phrase Error in 91948, id 78: phrase 'Was soll ich sagen , einfach genial!\n\n' not in text
# Phrase Error in 91948, id 84: phrase 'Wäre in LOC Mittelklasse.\n\n' not in text
# Phrase Error in 91948, id 102: phrase 'Das war der letzte Besuch!\n\n' not in text
# Phrase Error in 91948, id 130: phrase 'Dafür nochmals herzlichen Dank.\n\n' not in text
# Phrase Error in 91948, id 153: phrase 'Sehr gutes LOC.\n\n' not in text
# Phrase Error in 91948, id 187: phrase '- Es war schon mal deutlich besser.\n\n' not in text
# Phrase Error in 91951, id 764: phrase 'nicht gut.\n\n' not in text
# Phrase Error in 91954, id 285: phrase 'Service.\n' not in text
# Phrase Error in 91957, id 807: phrase 'Kommen sicher wieder.\n' not in text
# Phrase Error in 91957, id 819: phrase 'kommen gerne wieder\n' not in text
# Phrase Error in 91957, id 862: phrase 'wenig Abstand zwischen den Tischen.\n' not in text
# Phrase Error in 91957, id 914: phrase 'Immer wieder gerne!!!\n' not in text
# Phrase Error in 91957, id 914: phrase 'Immer wieder gerne!!!\n' not in text
# Phrase Error in 91957, id 915: phrase 'Bald wieder!\n' not in text
# Phrase Error in 91957, id 917: phrase 'Unverschämtheit.\n' not in text
# Phrase Error in 91957, id 917: phrase 'Unverschämtheit.\n' not in text
# Phrase Error in 91957, id 965: phrase 'freundlich und speditiv.\n' not in text
# Phrase Error in 91957, id 993: phrase 'Es war ein rundum gelungener Abend.\n' not in text
# Phrase Error in 91957, id 997: phrase 'Wir hatten zwei wunderschöne Abende und alles hat gepasst.\n' not in text
# Processing and validation complete.

# %% [markdown]
# ## Majority vote

# %%
import os
import json
import glob
from collections import Counter, defaultdict

# --- Helper functions ---
def get_frequency_for_counts(counts, minimum):
    """Return the frequency count based on minimum appearance across splits."""
    return sorted(counts, reverse=True)[0:minimum][minimum-1]

def get_unique_keys(dict_list):
    """Return all unique keys across a list of dictionaries."""
    unique_keys = set()
    for d in dict_list:
        unique_keys.update(d.keys())
    return list(unique_keys)

def merge_aspect_lists(aspect_lists, minimum_appearance=2, oid=None):
    """
    Merge multiple aspect lists based on a minimum appearance, 
    with warning for low-frequency aspects.
    """
    counter_exclude = 0
    aspect_lists_counter = []
    for aspect_list in aspect_lists:
        aspect_counter = dict(Counter(["#####".join(aspect) for aspect in aspect_list]))
        aspect_lists_counter.append(aspect_counter)
        
    unique_tuples = get_unique_keys(aspect_lists_counter)

    label = []
    for tuple_str in unique_tuples:
        counts = [asp.get(tuple_str, 0) for asp in aspect_lists_counter]
        total_count = sum(counts)
        
        if total_count < minimum_appearance:
            counter_exclude += 1
            continue  # skip weak aspects
        
        count_tuple = get_frequency_for_counts(counts, minimum_appearance)
        tuple_reverse = tuple(tuple_str.split("#####"))
        label += count_tuple * [tuple_reverse]
        
    return label, counter_exclude


# --- Main script ---
RESULTS_DIR = "results_crowd"
OUTPUT_FILE = "final/trainset_crowd.jsonl"
os.makedirs("final", exist_ok=True)

# Load all annotator files
files = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.jsonl")))
print(f"Found {len(files)} annotator files.")

# Group entries by ID
entries_by_id = defaultdict(list)

def load_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        return [json.loads(line) for line in f if line.strip()]

for path in files:
    for entry in load_jsonl(path):
        entries_by_id[entry["id"]].append(entry)

# Merge by majority vote
merged_entries = []
for oid, entry_list in sorted(entries_by_id.items(), key=lambda x: int(x[0])):
    if not entry_list:
        continue

    text = entry_list[0]["text"]
    original_id = entry_list[0]["original_id"]

    # Collect all label sets
    label_sets = [e.get("labels", []) for e in entry_list]

    # Merge with majority voting
    merged_labels, excluded = merge_aspect_lists(label_sets, minimum_appearance=2, oid=oid)

    merged_entries.append({
        "id": str(oid),
        "original_id": original_id,
        "text": text,
        "labels": merged_labels
    })

# Save merged dataset
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    for entry in merged_entries:
        json.dump(entry, f, ensure_ascii=False)
        f.write("\n")

print(f"✅ Merged dataset written to {OUTPUT_FILE} with {len(merged_entries)} entries.")
# Out:
# Found 15 annotator files.
# ✅ Merged dataset written to final/trainset_crowd.jsonl with 1000 entries.

# %% [markdown]
# ## Remove conflict

# %%
import json

INPUT_FILE = "final/trainset_crowd.jsonl"
OUTPUT_FILE = "final/trainset_crowd_noconflict.jsonl"

with open(INPUT_FILE, "r", encoding="utf-8") as f_in, open(OUTPUT_FILE, "w", encoding="utf-8") as f_out:
    for line in f_in:
        if not line.strip():
            continue
        entry = json.loads(line)

        # filter out labels with conflict polarity
        filtered_labels = [lbl for lbl in entry.get("labels", []) if lbl[1] != "conflict"]

        entry["labels"] = filtered_labels
        json.dump(entry, f_out, ensure_ascii=False)
        f_out.write("\n")

print(f"✅ File cleaned and saved to {OUTPUT_FILE}")
# Out:
# ✅ File cleaned and saved to final/trainset_crowd_noconflict.jsonl

# %%
import json

# file_name = "../../11_annotations/ground_truth/testset.jsonl"
file_name = "final/trainset_crowd_noconflict.jsonl"

# ===== CONFIG =====
include_conflict = False  # <-- SWITCH: set False to remove Conflict column
categories = ['ambiente', 'essen', 'gesamteindruck', 'preis', 'service']
# ==================

# Define polarity order and labels
if include_conflict:
    polarities = ['positive', 'negative', 'neutral', 'conflict']
else:
    polarities = ['positive', 'negative', 'neutral']

# Initialize stats
stats = {cat: {pol: {'explicit': 0, 'implicit': 0}
               for pol in polarities} for cat in categories}

# Read JSONL file
with open(file_name, "r", encoding="utf-8") as f:
    for line in f:
        entry = json.loads(line)
        for cat, pol, phrase in entry["labels"]:
            # Map German to English polarities
            pol_map = {
                'Positiv': 'Positive',
                'Negativ': 'Negative',
                'Neutral': 'Neutral',
                'Konflikt': 'Conflict'
            }
            pol_eng = pol_map.get(pol, pol)
            if cat in stats and pol_eng in stats[cat]:
                if phrase == "NULL":
                    stats[cat][pol_eng]['implicit'] += 1
                else:
                    stats[cat][pol_eng]['explicit'] += 1

# Prepare totals for each column
col_totals = {pol: {'explicit': 0, 'implicit': 0} for pol in polarities}
total_totals = {'explicit': 0, 'implicit': 0}

# ===== LaTeX OUTPUT =====
print(r"\begin{table}[h!]")
print(r"\centering")
print(
    r"\caption{Counts of polarity triplets by category, with explicit/implicit split}")
print(r"\label{tab:triplet_counts}")

# Define column alignment
col_format = "l" + "cc" * len(polarities) + "cc"
print(r"\begin{tabular}{" + col_format + "}")

# First header row
first_header = [" "]
for pol in polarities:
    first_header.append(r"\multicolumn{2}{c}{\textbf{" + pol + "}}")
first_header.append(r"\multicolumn{2}{c}{\textbf{Total}}")
print(" & ".join(first_header) + r" \\ \hline")

# Second header row
second_header = [r"\textbf{Aspect Category}"]
for _ in polarities + ["Total"]:
    second_header += [r"\textbf{Expl.}", r"\textbf{Impl.}"]
print(" & ".join(second_header) + r"\\")
print(r"\midrule")

# Data rows
for cat in categories:
    row = [cat]
    total_explicit = 0
    total_implicit = 0
    for pol in polarities:
        e = stats[cat][pol]['explicit']
        i = stats[cat][pol]['implicit']
        row += [str(e), str(i)]
        total_explicit += e
        total_implicit += i
        col_totals[pol]['explicit'] += e
        col_totals[pol]['implicit'] += i
    total_totals['explicit'] += total_explicit
    total_totals['implicit'] += total_implicit
    row += [str(total_explicit), str(total_implicit)]
    print(" & ".join(row) + r" \\")

# Totals row
print(r"\hline")
totals_row = [r"Total"]
for pol in polarities:
    totals_row.append(str(col_totals[pol]['explicit']))
    totals_row.append(str(col_totals[pol]['implicit']))
totals_row.append(str(total_totals['explicit']))
totals_row.append(str(total_totals['implicit']))
print(" & ".join(totals_row) + r" \\")
print(r"\bottomrule")
print(r"\end{tabular}")
print(r"\end{table}")
# Out:
# \begin{table}[h!]
# \centering
# \caption{Counts of polarity triplets by category, with explicit/implicit split}
# \label{tab:triplet_counts}
# \begin{tabular}{lcccccccc}
#   & \multicolumn{2}{c}{\textbf{positive}} & \multicolumn{2}{c}{\textbf{negative}} & \multicolumn{2}{c}{\textbf{neutral}} & \multicolumn{2}{c}{\textbf{Total}} \\ \hline
# \textbf{Aspect Category} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.} & \textbf{Expl.} & \textbf{Impl.}\\
# \midrule
# ambiente & 81 & 3 & 26 & 8 & 0 & 0 & 107 & 11 \\
# essen & 232 & 19 & 134 & 26 & 21 & 3 & 387 & 48 \\
# gesamteindruck & 26 & 77 & 16 & 62 & 1 & 1 & 43 & 140 \\
# preis & 8 & 2 & 20 & 16 & 2 & 1 & 30 & 19 \\
# service & 128 & 10 & 79 & 34 & 3 & 1 & 210 & 45 \\
# \hline
# Total & 475 & 111 & 275 & 146 & 27 & 6 & 777 & 263 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# <hr>

# %% [markdown]
# ### Metadata and Comment Analysis

# %%
import json
from collections import defaultdict

# Define valid categories and polarities (with English mapping)
valid_categories = {"essen", "preis", "ambiente", "gesamteindruck", "service"}
valid_polarities_map = {
    "negativ": "negative",
    "positiv": "positive",
    "neutral": "neutral",
    "konflikt": "conflict",
    "NULL": "NULL"
}

# Load JSON file
with open("data/students_raw.json", "r", encoding="utf-8") as f:
    data = json.load(f)

annotator_data = defaultdict(list)

# Process data
for item in data:
    task_data = item.get("data", {})
    task_id = task_data.get("id")
    original_id = task_data.get("original_id", task_id)
    text = task_data.get("text", "")

    for ann in item.get("annotations", []):
        completed_by = ann.get("completed_by")
        result_map = {}
        meta_dict = {}
        comments_list = []

        for result in ann.get("result", []):
            rid = result.get("id")
            if rid not in result_map:
                result_map[rid] = {"explicit": [], "implicit": False}

            from_name = result.get("from_name")
            val = result.get("value", {})

            if from_name == "category_polarity":
                for lbl in val.get("labels", []):
                    parts = lbl.split("-")
                    category = parts[0].lower()
                    polarity = parts[1].lower() if len(parts) > 1 else "NULL"
                    result_map[rid]["explicit"].append([category, polarity, val.get("text", "NULL")])

            elif from_name == "implicit":
                result_map[rid]["implicit"] = True

            elif from_name == "meta":
                # Collect meta choices
                choices = val.get("choices", [])
                if choices:
                    meta_dict["choices"] = choices

            elif from_name == "comment":
                # Collect free text comments
                comment_texts = val.get("text", [])
                comments_list.extend(comment_texts)

        labels_list = []
        for res in result_map.values():
            for lbl in res["explicit"]:
                if res["implicit"]:
                    lbl[2] = "NULL"
                # Translate polarity to English
                lbl[1] = valid_polarities_map.get(lbl[1], lbl[1])
                labels_list.append(lbl)

        if labels_list:
            annotator_data[completed_by].append({
                "id": str(task_id),
                "original_id": str(original_id),
                "text": text,
                "labels": labels_list,
                "meta": meta_dict,
                "comment_authors": comments_list
            })

# Validation and saving
for annotator, entries in annotator_data.items():
    filename = f"results_single_meta/{annotator}.jsonl"
    with open(filename, "w", encoding="utf-8") as f:
        for entry in entries:
            json.dump(entry, f, ensure_ascii=False)
            f.write("\n")

    # Checks
    if len(entries) != 200:
        # print(f"Length Error: Annotator {annotator} has {len(entries)} entries, expected 200.")
        None

    for entry in entries:
        for lbl in entry["labels"]:
            category, polarity, phrase = lbl
            # Check category
            if category not in valid_categories:
                print(f"Category Error in annotator {annotator}, id {entry['id']}: invalid category '{category}'")
            # Check polarity
            if polarity not in {"negative", "positive", "neutral", "conflict", "NULL"}:
                print(f"Polarity Error in annotator {annotator}, id {entry['id']}: invalid polarity '{polarity}'")
            # Check phrase exists in text if not NULL
            if phrase != "NULL" and phrase not in entry["text"]:
                print(f"Phrase Error in annotator {annotator}, id {entry['id']}: phrase '{phrase}' not in text")

print("Processing and validation complete.")
# Out:
# Phrase Error in annotator 86020, id 201: phrase 'Kellner „Bruno“.\n' not in text
# Category Error in annotator 88190, id 467: invalid category 'implizit'
# Category Error in annotator 88190, id 506: invalid category 'implizit'
# Category Error in annotator 87069, id 406: invalid category 'implizit'
# Phrase Error in annotator 87560, id 535: phrase 'Kaninchen.\n' not in text
# Category Error in annotator 86108, id 601: invalid category 'implizit'
# Category Error in annotator 86108, id 606: invalid category 'implizit'
# Category Error in annotator 86108, id 609: invalid category 'implizit'
# Phrase Error in annotator 15658, id 953: phrase 'Service.\n' not in text
# Processing and validation complete.

# %%
import os
import json
import pandas as pd
from collections import Counter

folder = "results_single_meta"
rows = []

# Loop through all jsonl files
for filename in os.listdir(folder):
    if filename.endswith(".jsonl"):
        annotator_id = filename.replace(".jsonl", "")
        counter = Counter()
        comment_count = 0

        with open(os.path.join(folder, filename), "r", encoding="utf-8") as f:
            for line in f:
                entry = json.loads(line)

                # Count meta choices
                meta = entry.get("meta", {})
                choices = meta.get("choices", [])
                counter.update(choices)
                text = entry.get("text", [])
                labels = entry.get("labels", [])
                # Count comments
                comments = entry.get("comment_authors", [])
                if comments == []:
                    continue
                else:
                    print(text, "\n", labels, "\n", comments, "\n\n")
                comment_count += len(comments)

        rows.append({
            "annotator": annotator_id,
            # K = Fehlender Kontext aus der Bewertung könnte die Annotation beeinflussen.
            "K": counter.get("K", 0),
            # S = Die Annotation war schwierig.
            "S": counter.get("S", 0),
            "total_choices": sum(counter.values()),
            "comments": comment_count
        })

# Create dataframe
df = pd.DataFrame(rows)
print(df)

# Save to CSV (optional)
df.to_csv("meta_counts_with_comments.csv", index=False)
# Out:
# Selbst unter Corona hatte das Restaurant sein Level gehalten.
#  [['gesamteindruck', 'positive', 'NULL']]
#  ['Die Frage ist halt was gehalten wurde. Das Essen, der Service etc.? Hätte daher Gesamteindruck implizit gesagt']
#
#
# Das Restaurant ist LOC und die Atmosphäre gleicht eher fast food als vera cucina italiana!
#  [['ambiente', 'negative', 'Atmosphäre']]
#  ["Nehme an das 'LOC' durch die Anonymisierung entstanden ist"]
#
#
# Sehr gute Kohlparty, Essen ausgezeichnet, DJ spitze.
#  [['essen', 'positive', 'Essen']]
#  ['Kohlparty bezieht sich wohl eher auf ein Event']
#
#
# Ich war in der RESTAURANT_NAME mit meiner Familie und kann wirklich nur ausschließlich positiv darüber berichten.
#  [['gesamteindruck', 'positive', 'NULL']]
#  ['der Restaurantname kann ja auch Target sein, aber da verdeckt wäre das meiner Meinung nach implizit']
#
#
# Leider war der Hauptgang Rinderfilet so zäh und durchwachsen dass dies den guten Gesamteindruck nachhaltig beschädigt hat.
#  [['essen', 'conflict', 'Rinderfilet']]
#  ['Frage ist ob der Gesamteindruck sich auf das Restaurant oder auf das gesamte Gängemenü bezieht']
#
#
# Aber es gab zu viele "aber" man ist freundlich, hat sich hier aber doch sehr vom Ruf des Fernsehkochs abhängig gemacht.
#  [['gesamteindruck', 'conflict', 'NULL']]
#  ['Keine wirklichen impliziten Marker ersichtlich']
#
#
# Das findet man sonst nicht, und macht die Faszination LOC aus.
#  [['gesamteindruck', 'positive', 'NULL']]
#  ['Impliziter Marker nicht ersichtlich']
#
#
# Die Brez‘n Suppe ist der Hammer, das Gröstl eine Riesenportion Geschmack.
#  [['essen', 'positive', 'Brez‘n Suppe']]
#  ['Ein Nicht-Bayer würde vermutlich nur die Suppe annotieren']
#
#
# Aber Pommes gibts es wesentlich leckere (die "Schalenreste" an den Pommes vermitteln vll.
#  [['essen', 'negative', 'Pommes']]
#  ['Satz abgeschnitten']
#
#
# Dieser sollte mal an einer Schulung teilnehmen in der Ihm der korrekte Umgang mit Gästen und Kollegen näher gebracht wird.
#  [['service', 'negative', 'NULL']]
#  ['Impliziter Marker nicht ersichtlich']
#
#
# Umso größer dann die Enttäuschung !
#  [['gesamteindruck', 'negative', 'NULL']]
#  ['Enttäuschung von was? Essen, Ambiente etc. ? Im Zweifle Gesamteindruck']
#
#
# "Übrigens, das Ehepaar, welches nach uns an unserem Tisch Platz nahm, sah sich genötigt, sich persönlich auf die Suche nach einen/r Servicemitarbeiter/in zu begeben.
#  [['service', 'negative', 'Servicemitarbeiter/in']]
#  ['Weil keine rumliefen nehme ich mal an']
#
#
# DANKESCHÖN
#  [['gesamteindruck', 'positive', 'NULL']]
#  ['Bedankt sich für was?']
#
#
# 100g auf einer durchweichten Scheibe Brot mit Ruccolasalat 14€.
#  [['essen', 'negative', 'Scheibe Brot'], ['essen', 'negative', 'Ruccolasalat'], ['preis', 'negative', 'NULL']]
#  ['Impliziert einen überteuerten Preis, ohne Marker allerdings. Lediglich der Preis wird hier genannt.']
#
#
# Ambiente toll , Essen überpreist und das man der Stiefmutter gratuliert ohne was zu hinterfragen ist schon sehr schmerzhaft .. brauch ich nicht nochmal .
#  [['ambiente', 'positive', 'Ambiente'], ['preis', 'negative', 'Essen']]
#  ['versteh den Part mit der Stiefmutter nicht']
#
#
# Burger geschmacklich Ok, Burger-Buns zu hart, Bedienung hektisch, aber trotzdem langsam und planlos (Bestellungen falsch ausgeführt).
#  [['essen', 'conflict', 'Burger'], ['service', 'negative', 'Bedienung']]
#  ['kann dazu verleiten dass auch die Burger Buns mit annotiert werden']
#
#
# Essen war mittelmäßig, Preise Düsseldorfer Niveau
#  [['essen', 'neutral', 'Essen'], ['preis', 'negative', 'Preise']]
#  ['Düsseldorf gilt als teuer; Wer das nicht weiß kann die Beurteilung des Preises vermutlich nicht richtig einordnen']
#
#
# 2mal Fisch, 1mal herzhafte südamerikanische (!)
#  [['essen', 'neutral', 'Fisch']]
#  ['Falscher Cut off durch sentence splitter']
#
#
# Man kann gerne zum Wagner weil es eine urige Kneipe ist, LOC sollte man aber nicht unbedingt.
#  [['gesamteindruck', 'positive', 'Wagner']]
#  ['Schwierig zu sagen was hier mit LOC gemeint ist']
#
#
# Beim Schweinebraten hat die Würze gefehlt, der dazugehörige Salat war fantastisch, die Kruste auch, der Kartoffelknödel war essbar, der Semmelknödel weniger.
#  [['essen', 'conflict', 'Schweinebraten'], ['essen', 'positive', 'Salat'], ['essen', 'neutral', 'Kartoffelknödel'], ['essen', 'negative', 'Semmelknödel']]
#  ['Schweinebraten war nicht würzig genug aber die Kruste gut daher Konflikt']
#
#
# Meine zuvor angesprochenen Allergien waren wohl nicht weiter von Interesse, entsprechendes Gemüse fand sich trotzdem in meinem Gericht.
#  [['service', 'negative', 'NULL'], ['essen', 'negative', 'NULL']]
#  ['Beides implizit, weil es vielleicht vom Service nicht weitergegeben wurde und schlussendlich das falsche Gericht auf dem Tisch stand']
#
#
# Das Essen ist zwar etwas teurer als sonst beim LOC, aber auch um mindestens 2 Klassen besser.
#  [['essen', 'conflict', 'Essen']]
#  ['Preis-Konflikt könnte hier genauso möglich sein']
#
#
# lang sehr wohl gefühlt!
#  [['gesamteindruck', 'positive', 'wohl']]
#  ['Unklar was mit lang gemeint ist']
#
#
# Auf nimmer Wiedersehen 👋 Stattdessen haben wir einen super Kaffee im Kaufmanns getrunken😀
#  [['essen', 'positive', 'super Kaffee']]
#  ['Auf nimmer wiedersehen ist komisch und macht keinen sinn']
#
#
# Also versuchten wir zu bezahlen, was auch nicht sehr einfach war, weil ca.
#  [['service', 'negative', 'NULL']]
#  ['macht gar keifnen sinn ']
#
#
# Die enge Bestuhlung im Lokal (französische Verhältnisse) lässt keinen anderen Schluss darauf zu.
#  [['ambiente', 'negative', 'Bestuhlung'], ['gesamteindruck', 'negative', 'Lokal']]
#  ['keine richtige aussage']
#
#
# Besuch in der RESTAURANT_NAME und immer wieder eine Reise wert!
#  [['gesamteindruck', 'positive', 'RESTAURANT_NAME']]
#  ['Platzhalter im Satz, da hat was nicht gestimmt']
#
#
# Das RESTAURANT_NAME ist ein durchschnittlicher LOC, den man ab und zu einmal für ein Essen aufsuchen kann ohne etwas Besonders zu erwarten.
#  [['gesamteindruck', 'neutral', 'LOC,'], ['essen', 'neutral', 'Essen']]
#  ['Platzhalter wurden nicht richtig befüllt']
#
#
# Würde RESTAURANT_NAME immer weiter empfehlen und werde auch immer, wenn ich in LOC bin, wieder kommen.
#  [['gesamteindruck', 'positive', 'RESTAURANT_NAME']]
#  ['Platzhalter nicht eingesetzt']
#
#
# Heute hier - neuer Standort, bin ich etwas sehr enttäuscht.
#  [['gesamteindruck', 'negative', 'NULL']]
#  ['kein richtiger Satz']
#
#
# Wir waren so enttäuscht , dass uns die Lust zum shoppen vergangen ist und wir sind nach LOC gefahren.
#  [['gesamteindruck', 'negative', 'LOC']]
#  ['Platzhalter ... was ist LOC']
#
#
# Die Kellnerin versuchte zu protestieren dass das Gericht beim Foto anders aussehen kann.
#  [['service', 'negative', 'Kellnerin']]
#  ['Satz macht keinen Sinn']
#
#
# Darauf angesprochen, meinte die Bedienung, dass Öl gesund sei........Die aufgerufenen Preise waren absolut überzogen.
#  [['preis', 'negative', 'Öl']]
#  ['Macht keinen Sinn']
#
#
# So eine Esskultur möchten wir eigentlich nicht und möchten es auch LOC die nächste Generation vermitteln.
#  [['ambiente', 'negative', 'LOC']]
#  ['platzhalter']
#
#
# Und heute -September 2023 haben wir auch gleiches bestellt,ist volle Enttäuschung -die Bratwürste sind um 2-3 cm kürzer geworden und Kartoffelsalat-wie Wassersuppe auch geschmacklos.
#  [['essen', 'negative', 'Bratwürste'], ['essen', 'negative', 'Kartoffelsalat-'], ['essen', 'negative', 'Wassersuppe']]
#  ['Wassersuppe XD']
#
#
# Leider kann ich den LOC nicht empfehlen .
#  [['gesamteindruck', 'negative', 'LOC']]
#  ['Platzhalter']
#
#
# Zum Eigentlichen, ja die Gerichte sind nett angerichtet, geschmacklich etwas über dem Durchschnitt der sonstigen Griechen.
#  [['essen', 'positive', 'Gerichte']]
#  ['macht keinen sinn der satz']
#
#
# LOC Bedienung, lange Wartezeit am Tisch.
#  [['service', 'negative', 'NULL']]
#  ['weiß leider noch immer nicht was LOC ist ...']
#
#
# 1 cm dicke Blutwurst, breiig wie Mus (statt kross gebraten)1 rundes Stück frittiertes Fleisch (was lt.
#  [['essen', 'negative', 'Blutwurst,'], ['essen', 'negative', 'Fleisch']]
#  ['macht keinen sinn, kann das nur abschätzen']
#
#
# Ich bin LOC und ich weiß, dass ich nicht die gleiche Küche wie in LOC finden kann, aber das ist eine echte Beleidilung für uns.
#  [['gesamteindruck', 'negative', 'LOC']]
#  ['macht keinen Sinn']
#
#
# Ich war jetzt schon oft bei Momo, da man in LOC ja keine Wahl hat, will man eine gute Pizza essen.
#  [['essen', 'positive', 'Pizza']]
#  ['macht keinen sinn der satz']
#
#
# Das LOC war ebenfalls trocken und hart und die „LOC“ hatte definitiv auch schon bessere Tage gesehen.
#  [['essen', 'negative', 'LOC'], ['gesamteindruck', 'negative', 'LOC“']]
#  ['was ist loc ?']
#
#
# Es war das Geld nicht wert.
#  [['gesamteindruck', 'negative', 'Es'], ['preis', 'negative', 'war']]
#  ['sehr unspezifisch']
#
#
# Auf nimmer Wiedersehen 👋 Stattdessen haben wir einen super Kaffee im Kaufmanns getrunken😀
#  [['essen', 'positive', 'Kaffee']]
#  ['Worauf war der Anfang bezogen?']
#
#
# Wo gibt es die beste Currywurst LOC, natürlich nur hier mitten im LOC.
#  [['essen', 'positive', 'Currywurst']]
#  ['Was ist das LOC']
#
#
# Das kleine Teil war dick, nicht platiniert, lauwarm und die Panade klebte naß am Holzteller.
#  [['essen', 'negative', 'dick']]
#  ['Was ist das kleine Teil']
#
#
# Das Restaurant ist LOC und die Atmosphäre gleicht eher fast food als vera cucina italiana!
#  [['ambiente', 'negative', 'Atmosphäre']]
#  ['Die erste hälfte des Satzes scheint unvollständig']
#
#
# Und kein deutsches, denkt man schon das man hier auch sehr gut essen kann.
#  [['essen', 'positive', 'essen']]
#  ['Es scheint die hälfte des satzes zu fehlen']
#
#
# Aber es gab zu viele "aber" man ist freundlich, hat sich hier aber doch sehr vom Ruf des Fernsehkochs abhängig gemacht.
#  [['service', 'positive', 'NULL'], ['gesamteindruck', 'negative', 'NULL']]
#  ['Satzbau ergibt nicht wirklich sinn']
#
#
# Früher hat man das antiquierte Ambiente nicht beachtet, weil die Steaks sehr gut waren.
#  [['essen', 'negative', 'Steaks'], ['ambiente', 'negative', 'Ambiente']]
#  ['Die Steaks scheinen nicht mehr so gut zu sein wie früher']
#
#
#    annotator   K   S  total_choices  comments
# 0      10189  25   8             33        18
# 1      12680   0   0              0         0
# 2      15658   9  17             26         3
# 3      21123   8  12             20         0
# 4      86001   4   0              4         0
# 5      86020   3   4              7         0
# 6      86108   0   0              0         1
# 7      86407   0   0              0         0
# 8      86725  17  10             27         1
# 9      87069  14   5             19        19
# 10     87560   0   3              3         0
# 11     87576   8  16             24         1
# 12     88190   4   5              9         3
# 13     88285   8   5             13         4
# 14     89770   5   0              5         0
